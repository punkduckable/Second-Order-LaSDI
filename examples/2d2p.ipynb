# %% [markdown]
# # About this Notebook
#
# This notebook should work whenever the FOM depends on two variables (t, x) and whenever the parameter vector, $\theta$, has two elements (there are two parameters). If your example does not fall into that category, use another notebook!
#
# # Training
#
# First, let us train a higher-order LaSDI model on the Burgers' equation data.
# If you want to load a pre-trained model from a save, go to the next cell.

# %%
# -------------------------------------------------------------------------------------------------
# Imports 
# -------------------------------------------------------------------------------------------------

import  os;
import  sys;

src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
utils_path  : str = os.path.join(src_path, "Utilities");
sys.path.append(src_path);
sys.path.append(utils_path);

import  random;
import  yaml;
import  logging;

import  torch
import  numpy;

from    Workflow    import  Save;
from    Enums       import  NextStep, Result
from    Sample      import  Run_Samples, Update_Train_Space;
from    Initialize  import  Initialize_Trainer;
from    Logging     import  Initialize_Logger, Log_Dictionary;
from    Plot        import  Plot_Reconstruction;



# -------------------------------------------------------------------------------------------------
# Setup
# -------------------------------------------------------------------------------------------------

# Set up the logger
Initialize_Logger(logging.INFO);
LOGGER  : logging.Logger    = logging.getLogger(__name__);

# Load the configuration.
cfg_file : str = 'Explicit.yml';
#cfg_file : str = 'Burgers.yml';
with open(cfg_file, 'r') as f:
    config : dict = yaml.safe_load(f);
Log_Dictionary(LOGGER = LOGGER, D = config, level = logging.DEBUG);

# Setup the trainer
trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config);



# -------------------------------------------------------------------------------------------------
# Train
# -------------------------------------------------------------------------------------------------

LOGGER.info("Training with %d epochs" % trainer.max_iter);

# generate initial training/test data
Run_Samples(trainer, config);



# Fetch the number of testing, training examples.
n_train : int   = param_space.n_train();
n_test  : int   = param_space.n_test();
n_IC    : int   = latent_dynamics.n_IC;

# initial training given training data
trainer.train();


# Select a random parameter combination to investigate.
index_plot  : int = random.randrange(0, n_test);
print("Plotting testing parameter combination number %d (%s = %s)" % (index_plot, str(param_space.param_names), str(param_space.test_space[index_plot, :])));

Plot_Reconstruction(
    X_True  = trainer.X_Test[index_plot],
    model   = trainer.model, 
    t_grid  = trainer.t_Test[index_plot].numpy(), 
    x_grid  = trainer.physics.X_Positions);


while (trainer.restart_iter < trainer.max_iter):
    if (trainer.restart_iter <= trainer.max_greedy_iter):
        # perform greedy sampling to pick up new samples
        Update_Train_Space(trainer, config);
        # update training data with newly picked samples
        Run_Samples(trainer, config);

    # train over given training data
    trainer.train();

    # Plot 
    Plot_Reconstruction(  
        X_True  = trainer.X_Test[index_plot],
        model   = trainer.model, 
        t_grid  = trainer.t_Test[index_plot].numpy(), 
        x_grid  = trainer.physics.X_Positions);


# Finally, save!
Save(   param_space         = param_space, 
        physics             = physics, 
        model               = model, 
        latent_dynamics     = latent_dynamics, 
        trainer             = trainer, 
        next_step           = NextStep.PickSample, 
        result              = Result.Success,
        restart_filename    = None);
# Out:
# 21:41:55.815 - Initialize:Initialize_Trainer:116 - INFO - Initializing Trainer (gplasdi)
# 21:41:55.815 - Initialize:Initialize_Trainer:116 - INFO - Initializing Trainer (gplasdi)
# 21:41:55.816 - ParameterSpace:__init__:193 - INFO - Initializing a ParameterSpace object with parameters ['a', 'w']
# 21:41:55.816 - ParameterSpace:__init__:193 - INFO - Initializing a ParameterSpace object with parameters ['a', 'w']
# 21:41:55.816 - ParameterSpace:__init__:201 - INFO - The testing set has 25 parameter combinations
# 21:41:55.816 - ParameterSpace:__init__:201 - INFO - The testing set has 25 parameter combinations
# 21:41:55.817 - ParameterSpace:__init__:208 - INFO - The training set has 4 parameter combinations
# 21:41:55.817 - ParameterSpace:__init__:208 - INFO - The training set has 4 parameter combinations
# 21:41:55.817 - Initialize:Initialize_Physics:262 - INFO - Initializing Physics (Explicit)
# 21:41:55.817 - Initialize:Initialize_Physics:262 - INFO - Initializing Physics (Explicit)
# 21:41:55.818 - Initialize:Initialize_Model:200 - INFO - Initializing Model (pair)
# 21:41:55.818 - Initialize:Initialize_Model:200 - INFO - Initializing Model (pair)
# 21:41:55.818 - Model:__init__:613 - INFO - Initializing an Autoencoder_Pair...
# 21:41:55.818 - Model:__init__:613 - INFO - Initializing an Autoencoder_Pair...
# 21:41:55.819 - Model:__init__:634 - INFO - Initializing the Displacement Autoencoder...
# 21:41:55.819 - Model:__init__:634 - INFO - Initializing the Displacement Autoencoder...
# 21:41:55.819 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 21:41:55.819 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 21:41:55.820 - Model:__init__:304 - INFO - Initializing the encoder...
# 21:41:55.820 - Model:__init__:304 - INFO - Initializing the encoder...
# 21:41:55.823 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 21:41:55.823 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 21:41:55.823 - Model:__init__:311 - INFO - Initializing the decoder...
# 21:41:55.823 - Model:__init__:311 - INFO - Initializing the decoder...
# 21:41:55.826 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 21:41:55.826 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 21:41:55.827 - Model:__init__:639 - INFO - Initializing the Velocity Autoencoder...
# 21:41:55.827 - Model:__init__:639 - INFO - Initializing the Velocity Autoencoder...
# 21:41:55.827 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 21:41:55.827 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 21:41:55.828 - Model:__init__:304 - INFO - Initializing the encoder...
# 21:41:55.828 - Model:__init__:304 - INFO - Initializing the encoder...
# 21:41:55.831 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 21:41:55.831 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 21:41:55.831 - Model:__init__:311 - INFO - Initializing the decoder...
# 21:41:55.831 - Model:__init__:311 - INFO - Initializing the decoder...
# 21:41:55.834 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 21:41:55.834 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 21:41:55.835 - DampedSpring:__init__:83 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = False
# 21:41:55.835 - DampedSpring:__init__:83 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = False
# 21:41:55.835 - GPLaSDI:__init__:152 - INFO - Initializing a GPLaSDI object
# 21:41:55.835 - GPLaSDI:__init__:152 - INFO - Initializing a GPLaSDI object
# 21:41:56.567 - __main__:<module>:53 - INFO - Training with 1000 epochs
# 21:41:56.567 - __main__:<module>:53 - INFO - Training with 1000 epochs
# 21:41:56.567 - Sample:Run_Samples:128 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 21:41:56.567 - Sample:Run_Samples:128 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 21:41:56.568 - Sample:Run_Samples:147 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 21:41:56.568 - Sample:Run_Samples:147 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 21:41:56.569 - Physics:generate_solutions:229 - INFO - Generating solution for 25 parameter combinations
# 21:41:56.569 - Physics:generate_solutions:229 - INFO - Generating solution for 25 parameter combinations
# 21:41:56.570 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 0, [0.9 0.9]
# 21:41:56.570 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 0, [0.9 0.9]
# 21:41:56.582 - Physics:generate_solutions:245 - INFO - 1/25 complete
# 21:41:56.582 - Physics:generate_solutions:245 - INFO - 1/25 complete
# 21:41:56.582 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 1, [0.9  0.95]
# 21:41:56.582 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 1, [0.9  0.95]
# 21:41:56.589 - Physics:generate_solutions:245 - INFO - 2/25 complete
# 21:41:56.589 - Physics:generate_solutions:245 - INFO - 2/25 complete
# 21:41:56.589 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 2, [0.9 1. ]
# 21:41:56.589 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 2, [0.9 1. ]
# 21:41:56.597 - Physics:generate_solutions:245 - INFO - 3/25 complete
# 21:41:56.597 - Physics:generate_solutions:245 - INFO - 3/25 complete
# 21:41:56.598 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 3, [0.9  1.05]
# 21:41:56.598 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 3, [0.9  1.05]
# 21:41:56.608 - Physics:generate_solutions:245 - INFO - 4/25 complete
# 21:41:56.608 - Physics:generate_solutions:245 - INFO - 4/25 complete
# 21:41:56.609 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 4, [0.9 1.1]
# 21:41:56.609 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 4, [0.9 1.1]
# 21:41:56.618 - Physics:generate_solutions:245 - INFO - 5/25 complete
# 21:41:56.618 - Physics:generate_solutions:245 - INFO - 5/25 complete
# 21:41:56.619 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 5, [0.95 0.9 ]
# 21:41:56.619 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 5, [0.95 0.9 ]
# 21:41:56.626 - Physics:generate_solutions:245 - INFO - 6/25 complete
# 21:41:56.626 - Physics:generate_solutions:245 - INFO - 6/25 complete
# 21:41:56.627 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 6, [0.95 0.95]
# 21:41:56.627 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 6, [0.95 0.95]
# 21:41:56.635 - Physics:generate_solutions:245 - INFO - 7/25 complete
# 21:41:56.635 - Physics:generate_solutions:245 - INFO - 7/25 complete
# 21:41:56.635 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 7, [0.95 1.  ]
# 21:41:56.635 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 7, [0.95 1.  ]
# 21:41:56.642 - Physics:generate_solutions:245 - INFO - 8/25 complete
# 21:41:56.642 - Physics:generate_solutions:245 - INFO - 8/25 complete
# 21:41:56.643 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 8, [0.95 1.05]
# 21:41:56.643 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 8, [0.95 1.05]
# 21:41:56.651 - Physics:generate_solutions:245 - INFO - 9/25 complete
# 21:41:56.651 - Physics:generate_solutions:245 - INFO - 9/25 complete
# 21:41:56.651 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 9, [0.95 1.1 ]
# 21:41:56.651 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 9, [0.95 1.1 ]
# 21:41:56.657 - Physics:generate_solutions:245 - INFO - 10/25 complete
# 21:41:56.657 - Physics:generate_solutions:245 - INFO - 10/25 complete
# 21:41:56.658 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 10, [1.  0.9]
# 21:41:56.658 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 10, [1.  0.9]
# 21:41:56.666 - Physics:generate_solutions:245 - INFO - 11/25 complete
# 21:41:56.666 - Physics:generate_solutions:245 - INFO - 11/25 complete
# 21:41:56.666 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 11, [1.   0.95]
# 21:41:56.666 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 11, [1.   0.95]
# 21:41:56.673 - Physics:generate_solutions:245 - INFO - 12/25 complete
# 21:41:56.673 - Physics:generate_solutions:245 - INFO - 12/25 complete
# 21:41:56.674 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 12, [1. 1.]
# 21:41:56.674 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 12, [1. 1.]
# 21:41:56.679 - Physics:generate_solutions:245 - INFO - 13/25 complete
# 21:41:56.679 - Physics:generate_solutions:245 - INFO - 13/25 complete
# 21:41:56.679 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 13, [1.   1.05]
# 21:41:56.679 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 13, [1.   1.05]
# 21:41:56.685 - Physics:generate_solutions:245 - INFO - 14/25 complete
# 21:41:56.685 - Physics:generate_solutions:245 - INFO - 14/25 complete
# 21:41:56.685 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 14, [1.  1.1]
# 21:41:56.685 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 14, [1.  1.1]
# 21:41:56.692 - Physics:generate_solutions:245 - INFO - 15/25 complete
# 21:41:56.692 - Physics:generate_solutions:245 - INFO - 15/25 complete
# 21:41:56.693 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 15, [1.05 0.9 ]
# 21:41:56.693 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 15, [1.05 0.9 ]
# 21:41:56.698 - Physics:generate_solutions:245 - INFO - 16/25 complete
# 21:41:56.698 - Physics:generate_solutions:245 - INFO - 16/25 complete
# 21:41:56.699 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 16, [1.05 0.95]
# 21:41:56.699 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 16, [1.05 0.95]
# 21:41:56.705 - Physics:generate_solutions:245 - INFO - 17/25 complete
# 21:41:56.705 - Physics:generate_solutions:245 - INFO - 17/25 complete
# 21:41:56.706 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 17, [1.05 1.  ]
# 21:41:56.706 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 17, [1.05 1.  ]
# 21:41:56.715 - Physics:generate_solutions:245 - INFO - 18/25 complete
# 21:41:56.715 - Physics:generate_solutions:245 - INFO - 18/25 complete
# 21:41:56.716 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 18, [1.05 1.05]
# 21:41:56.716 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 18, [1.05 1.05]
# 21:41:56.722 - Physics:generate_solutions:245 - INFO - 19/25 complete
# 21:41:56.722 - Physics:generate_solutions:245 - INFO - 19/25 complete
# 21:41:56.722 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 19, [1.05 1.1 ]
# 21:41:56.722 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 19, [1.05 1.1 ]
# 21:41:56.729 - Physics:generate_solutions:245 - INFO - 20/25 complete
# 21:41:56.729 - Physics:generate_solutions:245 - INFO - 20/25 complete
# 21:41:56.730 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 20, [1.1 0.9]
# 21:41:56.730 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 20, [1.1 0.9]
# 21:41:56.734 - Physics:generate_solutions:245 - INFO - 21/25 complete
# 21:41:56.734 - Physics:generate_solutions:245 - INFO - 21/25 complete
# 21:41:56.735 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 21, [1.1  0.95]
# 21:41:56.735 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 21, [1.1  0.95]
# 21:41:56.744 - Physics:generate_solutions:245 - INFO - 22/25 complete
# 21:41:56.744 - Physics:generate_solutions:245 - INFO - 22/25 complete
# 21:41:56.744 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 22, [1.1 1. ]
# 21:41:56.744 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 22, [1.1 1. ]
# 21:41:56.751 - Physics:generate_solutions:245 - INFO - 23/25 complete
# 21:41:56.751 - Physics:generate_solutions:245 - INFO - 23/25 complete
# 21:41:56.751 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 23, [1.1  1.05]
# 21:41:56.751 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 23, [1.1  1.05]
# 21:41:56.757 - Physics:generate_solutions:245 - INFO - 24/25 complete
# 21:41:56.757 - Physics:generate_solutions:245 - INFO - 24/25 complete
# 21:41:56.758 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 24, [1.1 1.1]
# 21:41:56.758 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 24, [1.1 1.1]
# 21:41:56.764 - Physics:generate_solutions:245 - INFO - 25/25 complete
# 21:41:56.764 - Physics:generate_solutions:245 - INFO - 25/25 complete
# 21:41:56.765 - Sample:Run_Samples:182 - INFO - Searching for training parameter 0, [0.9 0.9], in the testing set.
# 21:41:56.765 - Sample:Run_Samples:182 - INFO - Searching for training parameter 0, [0.9 0.9], in the testing set.
# 21:41:56.766 - Sample:Run_Samples:187 - INFO - Train parameter 0 is test parameter 0! Copying the solution and t_grid from the testing set!
# 21:41:56.766 - Sample:Run_Samples:187 - INFO - Train parameter 0 is test parameter 0! Copying the solution and t_grid from the testing set!
# 21:41:56.766 - Sample:Run_Samples:182 - INFO - Searching for training parameter 1, [0.9 1.1], in the testing set.
# 21:41:56.766 - Sample:Run_Samples:182 - INFO - Searching for training parameter 1, [0.9 1.1], in the testing set.
# 21:41:56.767 - Sample:Run_Samples:187 - INFO - Train parameter 1 is test parameter 4! Copying the solution and t_grid from the testing set!
# 21:41:56.767 - Sample:Run_Samples:187 - INFO - Train parameter 1 is test parameter 4! Copying the solution and t_grid from the testing set!
# 21:41:56.768 - Sample:Run_Samples:182 - INFO - Searching for training parameter 2, [1.1 0.9], in the testing set.
# 21:41:56.768 - Sample:Run_Samples:182 - INFO - Searching for training parameter 2, [1.1 0.9], in the testing set.
# 21:41:56.768 - Sample:Run_Samples:187 - INFO - Train parameter 2 is test parameter 20! Copying the solution and t_grid from the testing set!
# 21:41:56.768 - Sample:Run_Samples:187 - INFO - Train parameter 2 is test parameter 20! Copying the solution and t_grid from the testing set!
# 21:41:56.769 - Sample:Run_Samples:182 - INFO - Searching for training parameter 3, [1.1 1.1], in the testing set.
# 21:41:56.769 - Sample:Run_Samples:182 - INFO - Searching for training parameter 3, [1.1 1.1], in the testing set.
# 21:41:56.769 - Sample:Run_Samples:187 - INFO - Train parameter 3 is test parameter 24! Copying the solution and t_grid from the testing set!
# 21:41:56.769 - Sample:Run_Samples:187 - INFO - Train parameter 3 is test parameter 24! Copying the solution and t_grid from the testing set!
# 21:41:56.771 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 21:41:56.771 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 21:41:56.772 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #0 over 6 time steps
# 21:41:56.772 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #0 over 6 time steps
# 21:41:56.780 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 21:41:56.780 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 21:41:56.781 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 21:41:56.781 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 21:41:56.782 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 21:41:56.782 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 21:41:56.786 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 21:41:56.786 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 21:41:56.787 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 21:41:56.787 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 21:41:56.789 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #2 over 6 time steps
# 21:41:56.789 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #2 over 6 time steps
# 21:41:56.795 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #2.
# 21:41:56.795 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #2.
# 21:41:56.796 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 21:41:56.796 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 21:41:56.798 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #3 over 6 time steps
# 21:41:56.798 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #3 over 6 time steps
# 21:41:56.802 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 21:41:56.802 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 21:41:56.940 - GPLaSDI:train:275 - INFO - Training for 500 epochs (starting at 0, going to 500) with 4 parameters
# 21:41:56.940 - GPLaSDI:train:275 - INFO - Training for 500 epochs (starting at 0, going to 500) with 4 parameters
# 21:41:57.214 - GPLaSDI:train:715 - INFO - Iter: 00001/1000, Total: 3.656173, Recon D: 0.405103, Recon V: 0.461137, CR X: 0.460003, CR Z: 0.913619, Cons Z: 0.915291, Cons X: 0.026994, Roll D: 0.405526, Roll V: 0.460774, Roll ZD: 0.000091, Roll ZV: 0.000046, LD: 0.033123, Coef: 242.460663, max|c|: 33.6,
# 21:44:16.759 - GPLaSDI:train:715 - INFO - Iter: 00999/1000, Total: 0.043405, Recon D: 0.002153, Recon V: 0.002610, CR X: 0.006471, CR Z: 0.004567, Cons Z: 0.004908, Cons X: 0.002295, Roll D: 0.002180, Roll V: 0.002495, Roll ZD: 0.000007, Roll ZV: 0.000070, LD: 0.019054, Coef: 84.969742, max|c|: 08.9,
# 21:44:16.759 - GPLaSDI:train:715 - INFO - Iter: 00999/1000, Total: 0.043405, Recon D: 0.002153, Recon V: 0.002610, CR X: 0.006471, CR Z: 0.004567, Cons Z: 0.004908, Cons X: 0.002295, Roll D: 0.002180, Roll V: 0.002495, Roll ZD: 0.000007, Roll ZV: 0.000070, LD: 0.019054, Coef: 84.969742, max|c|: 08.9,
# 21:44:16.890 - GPLaSDI:train:715 - INFO - Iter: 01000/1000, Total: 0.036516, Recon D: 0.002025, Recon V: 0.002308, CR X: 0.005823, CR Z: 0.002230, Cons Z: 0.002580, Cons X: 0.002298, Roll D: 0.002069, Roll V: 0.002210, Roll ZD: 0.000003, Roll ZV: 0.000082, LD: 0.018553, Coef: 77.934021, max|c|: 06.9,
# 21:44:16.890 - GPLaSDI:train:715 - INFO - Iter: 01000/1000, Total: 0.036516, Recon D: 0.002025, Recon V: 0.002308, CR X: 0.005823, CR Z: 0.002230, Cons Z: 0.002580, Cons X: 0.002298, Roll D: 0.002069, Roll V: 0.002210, Roll ZD: 0.000003, Roll ZV: 0.000082, LD: 0.018553, Coef: 77.934021, max|c|: 06.9,
# /Users/stephany1/Documents/Projects/Second Order LaSDI/src/GPLaSDI.py:750: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict  = torch.load(self.path_checkpoint + '/' + 'checkpoint.pt');
# 21:44:16.897 - Plot:Plot_Reconstruction:115 - INFO - Making a Reconstruction plot with n_t = 501, n_x = 1001, and n_IC = 2
# 21:44:16.897 - Plot:Plot_Reconstruction:115 - INFO - Making a Reconstruction plot with n_t = 501, n_x = 1001, and n_IC = 2
# Function name      	Calls	Total time	Time/call
#
# Rollout Setup      	4511	8.384e+00	1.859e-03
#
# train_step         	1000	1.227e+02	1.227e-01
#
# Forward Pass       	4500	1.403e+01	3.117e-03
#
# Reconstruction Loss	4500	1.974e+00	4.387e-04
#
# Consistency Loss   	4500	3.621e+00	8.047e-04
#
# Chain Rule Loss    	4500	1.971e+01	4.380e-03
#
# Calibration        	1000	2.229e+00	2.229e-03
#
# Rollout Loss       	1000	1.764e+01	1.764e-02
#
# Backwards Pass     	1000	5.255e+01	5.255e-02
#
# Report             	1000	8.736e-01	8.736e-04
#
# finalize           	2	5.922e-03	2.961e-03
#
# new_sample         	1	1.149e+01	1.149e+01

# %% [markdown]
# # Loading From a Save
#
#
# If you instead want to load a saved model, we can load the restart file for post-training.

# %%
# Add src directory to the search path
import  os;
import  sys;
src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
sys.path.append(src_path);

import  yaml;
import  logging;

import  numpy; 
import  torch;

from    ParameterSpace  import  ParameterSpace;
from    Initialize      import  Initialize_Trainer;



# Specify the restart file you have.
filename    : str   = 'lasdi_04_30_2025_17_32.npy'
cfg_file    : str   = 'Explicit.yml'
with open(cfg_file, 'r') as f:
    config = yaml.safe_load(f)

file_path   : str   = os.path.join(os.path.join(os.path.pardir, "results"), filename);
restart_file        = numpy.load(file_path, allow_pickle = True).item()

trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config, restart_file)

# %% [markdown]
# # Post-processing

# %% [markdown]
# Setup data for post-processing:

# %%
n_coef          : int                       = latent_dynamics.n_coefs;
n_IC            : int                       = latent_dynamics.n_IC; 
n_p             : int                       = param_space.n_p; 

coefs           : numpy.ndarray             = trainer.best_coefs;           # shape = (n_train, n_coefs).
X_Train         : list[list[torch.Tensor]]  = trainer.X_Train;              # len = n_train. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM train solve
X_Test          : list[list[torch.Tensor]]  = trainer.X_Test;               # len = n_test. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM test solve.
t_Train         : list[torch.Tensor]        = trainer.t_Train;              # len = n_train. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM train solve.
t_Test          : list[torch.Tensor]        = trainer.t_Test;               # len = n_test. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM test solve.
n_samples       : int                       = trainer.n_samples;

param_train     : numpy.ndarray             = param_space.train_space;      # shape = (n_train, n_p)
param_test      : numpy.ndarray             = param_space.test_space;       # shape = (n_test, n_p)
param_names     : list[str]                 = param_space.param_names;

test_meshgrid   : tuple[numpy.ndarray]      = param_space.test_meshgrid;    # len = n_p. i'th element is meshgrid for i'th parameter.
test_grid_sizes : list[int]                 = param_space.test_grid_sizes;  # len = n_p. i'th element holds the number of values of the i'th parameter in the test set.
n_init_train    : int                       = param_space.n_init_train;     # The initial number of combinations of parameters in the training set.
n_train         : int                       = param_space.n_train();
n_test          : int                       = param_space.n_test();

X_Positions     : numpy.ndarray             = physics.X_Positions;          # Spatial discretization of FOM problem domain.
assert(X_Positions.ndim == 1);

# %% [markdown]
# ## Gaussian-process uncertainty evaluation
# For each combination of parameters, evaluate the coefficient GPs to generate a set of coefficients for the latent dynamics for that parameter combination. Then solve each latent dynamics forward in time.

# %%
# First, we need to import a few new things.
import os;
import sys;
physics_path    : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Physics");
utils_path      : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Utilities");
sys.path.append(physics_path);

from    sklearn.gaussian_process    import  GaussianProcessRegressor;

import  SolveROMs;
import  GaussianProcess;
from    Physics                     import  Physics;
from    Model                       import  Autoencoder, Autoencoder_Pair;

# Setup
model.cpu();



# Get a GP for each coefficient in the latent dynamics.
gp_list         : list[GaussianProcessRegressor]    = GaussianProcess.fit_gps(param_space.train_space, coefs);

Zis_samples     : list[list[numpy.ndarray]] = SolveROMs.sample_roms(model, physics, latent_dynamics, gp_list, param_test, t_Test, n_samples);    # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_samples, n_z)
Zis_mean        : list[list[numpy.ndarray]] = SolveROMs.average_rom(model, physics, latent_dynamics, gp_list, param_test, t_Test);               # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_z)
# Out:
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %% [markdown]
# Now, decode the latent trajectories and compare them to the test set. Use these values to compute some errors.

# %%
# Set up arrays to hold the average error between X_pred_mean and X_test, as well as the std of 
# the predictions.
mean_rel_error   : list[numpy.ndarray]   = [];
max_std          : list[numpy.ndarray]   = [];
for d in range(n_IC):
    mean_rel_error.append(  numpy.zeros(n_test, dtype = numpy.float32));
    max_std.append(         numpy.zeros(n_test, dtype = numpy.float32));



# Pass the samples through the decoder. The way this works depends on what kind of model we are using. 
if(isinstance(model, Autoencoder)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        X_pred_mean.append([model.Decode(torch.Tensor(Zis_mean[i][0])).detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_X_Pred   : numpy.ndarray            = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            X_Pred_ij                           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]));
            ith_X_Pred[:, j, :]                 = X_Pred_ij.detach().numpy();

        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_X_Pred.std(axis = 1).max();
    
    

elif(isinstance(model, Autoencoder_Pair)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        Disp_Pred_mean_i, Vel_Pred_mean_i   = model.Decode(torch.Tensor(Zis_mean[i][0]), torch.Tensor(Zis_mean[i][1]));
        X_pred_mean.append([Disp_Pred_mean_i.detach().numpy(), Vel_Pred_mean_i.detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_Disp_Pred   : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);
        ith_Vel_Pred    : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            Disp_Pred_ij, Vel_Pred_ij           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]), torch.Tensor(Zis_samples[i][1][:, j, :]));
            ith_Disp_Pred[:, j, :]              = Disp_Pred_ij.detach().numpy();
            ith_Vel_Pred[:, j, :]               = Vel_Pred_ij.detach().numpy();


        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_Disp_Pred.std(axis = 1).max();
        max_std[1][i]                           = ith_Vel_Pred.std(axis = 1).max();



# For each d \in {0, 1, ... , n_{IC} - 1} and k \in {1, 2, ... , n_test - 1}, find the mean 
# error between X_Pred_mean[d][k, ...] and X_test[d][k, ...].
for d in range(n_IC):
    for k in range(n_test):        
        # Extract the prediction, true values for the d'th component of the FOM solution when we use 
        # the k'th parameter value. These have shape (n_t, n_x).
        kth_X_Pred_d            : numpy.ndarray = X_pred_mean[k][d];
        kth_X_Test_d            : numpy.ndarray = X_Test[k][d].numpy();
        
        # For each compute the relative error between the predicted and true values of the d'th 
        # derivative of the FOM solution at each time step when we use the k'th combination of 
        # parameter values.
        kth_Relative_Errors_d   : numpy.ndarray = numpy.linalg.norm(kth_X_Pred_d - kth_X_Test_d, axis = 1) / numpy.linalg.norm(kth_X_Test_d, axis = 1);
        mean_rel_error[d][k]                    = kth_Relative_Errors_d.max();



# Get the mean and std of each coefficient's distribution when we evaluate the posterior coefficient 
# distributions at each testing parameter value. We then reshape these arrays to have shape 
# (N(1), ... , N(n_p)), where N(k) is the number of distinct values of the k'th parameter in the 
# training set. The i(1), ... , i(n_p), j element of the d'th element of these lists will hold the 
# mean and std of the distribution of the j'th parameter when we use the i(k)'th value of the k'th 
# parameter.
gp_pred_mean, gp_pred_std = GaussianProcess.eval_gp(gp_list, param_test);
gp_pred_mean    = gp_pred_mean.reshape(test_grid_sizes + [-1]);
gp_pred_std     = gp_pred_std.reshape(test_grid_sizes + [-1]);

# Reshape each element of mean_rel_error and max_std has shape (N(1), ... , N(n_p)), where N(k) 
# is the number of distinct values of the k'th parameter in the training set. The i(1), ... , i(n_p) 
# element of the d'th element of these lists will hold the mean error and std of the prediction of 
# the d'th derivative of the FOM solution when we use the i(k)'th value of the k'th parameter, 
# respectively.
for d in range(n_IC):
    mean_rel_error[d]   = mean_rel_error[d].reshape(test_grid_sizes);
    max_std[d]          = max_std[d].reshape(test_grid_sizes);

# %% [markdown]
# # Visualization

# %% [markdown]
# Plot mean and standard deviation of coefficient matrix.

# %%
import  Plot;


if(n_p == 2):
    Plot.Plot_GP2d( p1_mesh     = test_meshgrid[0], 
                    p2_mesh     = test_meshgrid[1], 
                    gp_mean     = gp_pred_mean, 
                    gp_std      = gp_pred_std, 
                    param_train = param_train, 
                    param_names = param_names, 
                    n_cols      = 5);
# Out:
# 21:51:05.228 - Plot:Plot_GP2d:516 - INFO - Producing GP plots with 55 coefficients. The parameters are ['a', 'w']
# 21:51:05.228 - Plot:Plot_GP2d:516 - INFO - Producing GP plots with 55 coefficients. The parameters are ['a', 'w']

# %%
for d in range(n_IC):
    if(d == 0):
        title_string : str = r'$max_{t} mean_{i} \|x \to \left(\tilde{u}_{\xi^*}^{i}(t, x) - u(t, x) \right) \|/\| x \to u(t, x)\|$';
    else:
        title_string : str = r'$max_{t} mean_{i} \left\|x \to \left( \frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*}^{i}(t, x) - \frac{d^{%d}}{dt^{%d}}u(t, x) \right) \right\|$' % (d, d, d, d);


    Plot.Plot_Heatmap2d(values          = mean_rel_error[d] * 100, 
                        param_space     = param_space,
                        title           = title_string);
# Out:
# 21:53:32.414 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:32.414 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:32.523 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:32.523 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.

# %%
import Plot; 

for d in range(n_IC):
    if(d == 0):
        title : str = r'$max_{(t, x)} \sqrt{ V \left[ \tilde{u}_{\xi^*} \right] }$';
    else:
        title : str = r'$max_{(t, x)} \sqrt{ V \left[\frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*} \right] }$' % (d, d);


    Plot.Plot_Heatmap2d(values          = max_std[d] * 100,
                        param_space     = param_space, 
                        title           = title);
# Out:
# 21:53:54.967 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:54.967 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:55.069 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.
# 21:53:55.069 - Plot:Plot_Heatmap2d:692 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 5 training points (4 initial) and 25 testing points.

# %%
import importlib
importlib.reload(Plot);

# Pick some parameter values.
a           : float                 = 0.9;
w           : float                 = 1.07; 
param_grid  : numpy.ndarray         = numpy.array([[a, w]]);

# Get the predicted solution using this parameter value.
X_True, t_Grid = physics.solve(param_grid[0]);


# Plot the predictions!
Plot.Plot_Prediction(
            model           = model, 
            physics         = physics, 
            latent_dynamics = latent_dynamics, 
            param_grid      = param_grid,
            gp_list         = gp_list, 
            n_samples       = n_samples, 
            X_True          = [X_True], 
            t_Grid          = [t_Grid]);
# Out:
# 14:06:31.034 - Plot:Plot_Prediction:281 - INFO - Solving the latent dynamics using 20 samples of the posterior distributions for 1 combinations of parameter values
# 14:06:31.034 - Plot:Plot_Prediction:281 - INFO - Solving the latent dynamics using 20 samples of the posterior distributions for 1 combinations of parameter values
# 14:06:31.359 - Plot:Plot_Prediction:316 - INFO - Computing mean/std of predictions for combination number 0.
# 14:06:31.359 - Plot:Plot_Prediction:316 - INFO - Computing mean/std of predictions for combination number 0.
# 14:06:31.360 - Plot:Plot_Prediction:317 - INFO - The Latent Trajectories combination number 0 has shape (n_t(0), n_samples, n_z) = (501, 20, 5)
# 14:06:31.360 - Plot:Plot_Prediction:317 - INFO - The Latent Trajectories combination number 0 has shape (n_t(0), n_samples, n_z) = (501, 20, 5)
