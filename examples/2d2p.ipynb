# %% [markdown]
# # About this Notebook
#
# This notebook should work whenever the FOM depends on two variables (t, x) and whenever the parameter vector, $\theta$, has two elements (there are two parameters). If your example does not fall into that category, use another notebook!
#
# # Training
#
# First, let us train a higher-order LaSDI model on the Burgers' equation data.
# If you want to load a pre-trained model from a save, go to the next cell.

# %%
# -------------------------------------------------------------------------------------------------
# Imports 
# -------------------------------------------------------------------------------------------------

import  os;
import  sys;

src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
utils_path  : str = os.path.join(src_path, "Utilities");
sys.path.append(src_path);
sys.path.append(utils_path);

import  random;
import  yaml;
import  logging;

import  torch
import  numpy;

from    Workflow    import  Save;
from    Enums       import  NextStep, Result
from    Sample      import  Run_Samples, Update_Train_Space;
from    Initialize  import  Initialize_Trainer;
from    Logging     import  Initialize_Logger, Log_Dictionary;
from    Plot        import  Plot_Reconstruction;



# -------------------------------------------------------------------------------------------------
# Setup
# -------------------------------------------------------------------------------------------------

# Set up the logger
Initialize_Logger(logging.INFO);
LOGGER  : logging.Logger    = logging.getLogger(__name__);

# Load the configuration.
cfg_file : str = 'Explicit.yml';
#cfg_file : str = 'Burgers.yml';
with open(cfg_file, 'r') as f:
    config : dict = yaml.safe_load(f);
Log_Dictionary(LOGGER = LOGGER, D = config, level = logging.DEBUG);

# Setup the trainer
trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config);



# -------------------------------------------------------------------------------------------------
# Train
# -------------------------------------------------------------------------------------------------

LOGGER.info("Training with %d epochs" % trainer.max_iter);

# generate initial training/test data
Update_Train_Space(trainer, config);
Run_Samples(trainer, config);



# Fetch the number of testing, training examples.
n_train : int   = param_space.n_train();
n_test  : int   = param_space.n_test();
n_IC    : int   = latent_dynamics.n_IC;

# initial training given training data
trainer.train();


# Select a random parameter combination to investigate.
index_plot  : int = random.randrange(0, n_test);
print("Plotting testing parameter combination number %d (%s = %s)" % (index_plot, str(param_space.param_names), str(param_space.test_space[index_plot, :])));

Plot_Reconstruction(
    X_True  = trainer.X_Test[index_plot],
    model   = trainer.model, 
    t_grid  = trainer.t_Test[index_plot].numpy(), 
    x_grid  = trainer.physics.X_Positions);


while (trainer.restart_iter < trainer.max_iter):
    if (trainer.restart_iter <= trainer.max_greedy_iter):
        # perform greedy sampling to pick up new samples
        Update_Train_Space(trainer, config);
        # update training data with newly picked samples
        Run_Samples(trainer, config);

    # train over given training data
    trainer.train();

    # Plot 
    Plot_Reconstruction(  
        X_True  = trainer.X_Test[index_plot],
        model   = trainer.model, 
        t_grid  = trainer.t_Test[index_plot].numpy(), 
        x_grid  = trainer.physics.X_Positions);


# Finally, save!
Save(   param_space         = param_space, 
        physics             = physics, 
        model               = model, 
        latent_dynamics     = latent_dynamics, 
        trainer             = trainer, 
        next_step           = NextStep.PickSample, 
        result              = Result.Success,
        restart_filename    = None);
# Out:
# 16:27:56.303 - Initialize:Initialize_Trainer:116 - INFO - Initializing Trainer (gplasdi)
# 16:27:56.303 - Initialize:Initialize_Trainer:116 - INFO - Initializing Trainer (gplasdi)
# 16:27:56.303 - ParameterSpace:__init__:193 - INFO - Initializing a ParameterSpace object with parameters ['A', 'w']
# 16:27:56.303 - ParameterSpace:__init__:193 - INFO - Initializing a ParameterSpace object with parameters ['A', 'w']
# 16:27:56.304 - ParameterSpace:__init__:201 - INFO - The testing set has 25 parameter combinations
# 16:27:56.304 - ParameterSpace:__init__:201 - INFO - The testing set has 25 parameter combinations
# 16:27:56.304 - ParameterSpace:__init__:208 - INFO - The training set has 4 parameter combinations
# 16:27:56.304 - ParameterSpace:__init__:208 - INFO - The training set has 4 parameter combinations
# 16:27:56.305 - Initialize:Initialize_Physics:262 - INFO - Initializing Physics (Explicit)
# 16:27:56.305 - Initialize:Initialize_Physics:262 - INFO - Initializing Physics (Explicit)
# 16:27:56.305 - Initialize:Initialize_Model:200 - INFO - Initializing Model (pair)
# 16:27:56.305 - Initialize:Initialize_Model:200 - INFO - Initializing Model (pair)
# 16:27:56.306 - Model:__init__:613 - INFO - Initializing an Autoencoder_Pair...
# 16:27:56.306 - Model:__init__:613 - INFO - Initializing an Autoencoder_Pair...
# 16:27:56.306 - Model:__init__:634 - INFO - Initializing the Displacement Autoencoder...
# 16:27:56.306 - Model:__init__:634 - INFO - Initializing the Displacement Autoencoder...
# 16:27:56.307 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:27:56.307 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:27:56.307 - Model:__init__:304 - INFO - Initializing the encoder...
# 16:27:56.307 - Model:__init__:304 - INFO - Initializing the encoder...
# 16:27:56.310 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:27:56.310 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:27:56.310 - Model:__init__:311 - INFO - Initializing the decoder...
# 16:27:56.310 - Model:__init__:311 - INFO - Initializing the decoder...
# 16:27:56.312 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:27:56.312 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:27:56.313 - Model:__init__:639 - INFO - Initializing the Velocity Autoencoder...
# 16:27:56.313 - Model:__init__:639 - INFO - Initializing the Velocity Autoencoder...
# 16:27:56.313 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:27:56.313 - Model:__init__:301 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:27:56.314 - Model:__init__:304 - INFO - Initializing the encoder...
# 16:27:56.314 - Model:__init__:304 - INFO - Initializing the encoder...
# 16:27:56.319 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:27:56.319 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 250, 100, 100, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:27:56.321 - Model:__init__:311 - INFO - Initializing the decoder...
# 16:27:56.321 - Model:__init__:311 - INFO - Initializing the decoder...
# 16:27:56.324 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:27:56.324 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 100, 100, 250, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:27:56.326 - DampedSpring:__init__:83 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = False
# 16:27:56.326 - DampedSpring:__init__:83 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = False
# 16:27:56.326 - GPLaSDI:__init__:152 - INFO - Initializing a GPLaSDI object
# 16:27:56.326 - GPLaSDI:__init__:152 - INFO - Initializing a GPLaSDI object
# 16:27:56.882 - __main__:<module>:53 - INFO - Training with 4000 epochs
# 16:27:56.882 - __main__:<module>:53 - INFO - Training with 4000 epochs
# 16:27:56.883 - Sample:Run_Samples:128 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 16:27:56.883 - Sample:Run_Samples:128 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 16:27:56.884 - Sample:Run_Samples:147 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 16:27:56.884 - Sample:Run_Samples:147 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 16:27:56.885 - Physics:generate_solutions:229 - INFO - Generating solution for 25 parameter combinations
# 16:27:56.885 - Physics:generate_solutions:229 - INFO - Generating solution for 25 parameter combinations
# 16:27:56.885 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 0, [0.9 0.9]
# 16:27:56.885 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 0, [0.9 0.9]
# 16:27:56.893 - Physics:generate_solutions:245 - INFO - 1/25 complete
# 16:27:56.893 - Physics:generate_solutions:245 - INFO - 1/25 complete
# 16:27:56.894 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 1, [0.9  0.95]
# 16:27:56.894 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 1, [0.9  0.95]
# 16:27:56.902 - Physics:generate_solutions:245 - INFO - 2/25 complete
# 16:27:56.902 - Physics:generate_solutions:245 - INFO - 2/25 complete
# 16:27:56.902 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 2, [0.9 1. ]
# 16:27:56.902 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 2, [0.9 1. ]
# 16:27:56.909 - Physics:generate_solutions:245 - INFO - 3/25 complete
# 16:27:56.909 - Physics:generate_solutions:245 - INFO - 3/25 complete
# 16:27:56.910 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 3, [0.9  1.05]
# 16:27:56.910 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 3, [0.9  1.05]
# 16:27:56.917 - Physics:generate_solutions:245 - INFO - 4/25 complete
# 16:27:56.917 - Physics:generate_solutions:245 - INFO - 4/25 complete
# 16:27:56.918 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 4, [0.9 1.1]
# 16:27:56.918 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 4, [0.9 1.1]
# 16:27:56.925 - Physics:generate_solutions:245 - INFO - 5/25 complete
# 16:27:56.925 - Physics:generate_solutions:245 - INFO - 5/25 complete
# 16:27:56.926 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 5, [0.95 0.9 ]
# 16:27:56.926 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 5, [0.95 0.9 ]
# 16:27:56.932 - Physics:generate_solutions:245 - INFO - 6/25 complete
# 16:27:56.932 - Physics:generate_solutions:245 - INFO - 6/25 complete
# 16:27:56.933 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 6, [0.95 0.95]
# 16:27:56.933 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 6, [0.95 0.95]
# 16:27:56.939 - Physics:generate_solutions:245 - INFO - 7/25 complete
# 16:27:56.939 - Physics:generate_solutions:245 - INFO - 7/25 complete
# 16:27:56.939 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 7, [0.95 1.  ]
# 16:27:56.939 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 7, [0.95 1.  ]
# 16:27:56.946 - Physics:generate_solutions:245 - INFO - 8/25 complete
# 16:27:56.946 - Physics:generate_solutions:245 - INFO - 8/25 complete
# 16:27:56.947 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 8, [0.95 1.05]
# 16:27:56.947 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 8, [0.95 1.05]
# 16:27:56.954 - Physics:generate_solutions:245 - INFO - 9/25 complete
# 16:27:56.954 - Physics:generate_solutions:245 - INFO - 9/25 complete
# 16:27:56.955 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 9, [0.95 1.1 ]
# 16:27:56.955 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 9, [0.95 1.1 ]
# 16:27:56.960 - Physics:generate_solutions:245 - INFO - 10/25 complete
# 16:27:56.960 - Physics:generate_solutions:245 - INFO - 10/25 complete
# 16:27:56.961 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 10, [1.  0.9]
# 16:27:56.961 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 10, [1.  0.9]
# 16:27:56.966 - Physics:generate_solutions:245 - INFO - 11/25 complete
# 16:27:56.966 - Physics:generate_solutions:245 - INFO - 11/25 complete
# 16:27:56.967 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 11, [1.   0.95]
# 16:27:56.967 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 11, [1.   0.95]
# 16:27:56.973 - Physics:generate_solutions:245 - INFO - 12/25 complete
# 16:27:56.973 - Physics:generate_solutions:245 - INFO - 12/25 complete
# 16:27:56.973 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 12, [1. 1.]
# 16:27:56.973 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 12, [1. 1.]
# 16:27:56.979 - Physics:generate_solutions:245 - INFO - 13/25 complete
# 16:27:56.979 - Physics:generate_solutions:245 - INFO - 13/25 complete
# 16:27:56.980 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 13, [1.   1.05]
# 16:27:56.980 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 13, [1.   1.05]
# 16:27:56.984 - Physics:generate_solutions:245 - INFO - 14/25 complete
# 16:27:56.984 - Physics:generate_solutions:245 - INFO - 14/25 complete
# 16:27:56.985 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 14, [1.  1.1]
# 16:27:56.985 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 14, [1.  1.1]
# 16:27:56.991 - Physics:generate_solutions:245 - INFO - 15/25 complete
# 16:27:56.991 - Physics:generate_solutions:245 - INFO - 15/25 complete
# 16:27:56.991 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 15, [1.05 0.9 ]
# 16:27:56.991 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 15, [1.05 0.9 ]
# 16:27:56.998 - Physics:generate_solutions:245 - INFO - 16/25 complete
# 16:27:56.998 - Physics:generate_solutions:245 - INFO - 16/25 complete
# 16:27:56.998 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 16, [1.05 0.95]
# 16:27:56.998 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 16, [1.05 0.95]
# 16:27:57.005 - Physics:generate_solutions:245 - INFO - 17/25 complete
# 16:27:57.005 - Physics:generate_solutions:245 - INFO - 17/25 complete
# 16:27:57.006 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 17, [1.05 1.  ]
# 16:27:57.006 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 17, [1.05 1.  ]
# 16:27:57.010 - Physics:generate_solutions:245 - INFO - 18/25 complete
# 16:27:57.010 - Physics:generate_solutions:245 - INFO - 18/25 complete
# 16:27:57.011 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 18, [1.05 1.05]
# 16:27:57.011 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 18, [1.05 1.05]
# 16:27:57.015 - Physics:generate_solutions:245 - INFO - 19/25 complete
# 16:27:57.015 - Physics:generate_solutions:245 - INFO - 19/25 complete
# 16:27:57.015 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 19, [1.05 1.1 ]
# 16:27:57.015 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 19, [1.05 1.1 ]
# 16:27:57.021 - Physics:generate_solutions:245 - INFO - 20/25 complete
# 16:27:57.021 - Physics:generate_solutions:245 - INFO - 20/25 complete
# 16:27:57.022 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 20, [1.1 0.9]
# 16:27:57.022 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 20, [1.1 0.9]
# 16:27:57.028 - Physics:generate_solutions:245 - INFO - 21/25 complete
# 16:27:57.028 - Physics:generate_solutions:245 - INFO - 21/25 complete
# 16:27:57.028 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 21, [1.1  0.95]
# 16:27:57.028 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 21, [1.1  0.95]
# 16:27:57.033 - Physics:generate_solutions:245 - INFO - 22/25 complete
# 16:27:57.033 - Physics:generate_solutions:245 - INFO - 22/25 complete
# 16:27:57.033 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 22, [1.1 1. ]
# 16:27:57.033 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 22, [1.1 1. ]
# 16:27:57.038 - Physics:generate_solutions:245 - INFO - 23/25 complete
# 16:27:57.038 - Physics:generate_solutions:245 - INFO - 23/25 complete
# 16:27:57.039 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 23, [1.1  1.05]
# 16:27:57.039 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 23, [1.1  1.05]
# 16:27:57.043 - Physics:generate_solutions:245 - INFO - 24/25 complete
# 16:27:57.043 - Physics:generate_solutions:245 - INFO - 24/25 complete
# 16:27:57.044 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 24, [1.1 1.1]
# 16:27:57.044 - Physics:generate_solutions:236 - INFO - Generating solution for parameter 24, [1.1 1.1]
# 16:27:57.049 - Physics:generate_solutions:245 - INFO - 25/25 complete
# 16:27:57.049 - Physics:generate_solutions:245 - INFO - 25/25 complete
# 16:27:57.050 - Sample:Run_Samples:182 - INFO - Searching for training parameter 0, [0.9 0.9], in the testing set.
# 16:27:57.050 - Sample:Run_Samples:182 - INFO - Searching for training parameter 0, [0.9 0.9], in the testing set.
# 16:27:57.050 - Sample:Run_Samples:187 - INFO - Train parameter 0 is test parameter 0! Copying the solution and t_grid from the testing set!
# 16:27:57.050 - Sample:Run_Samples:187 - INFO - Train parameter 0 is test parameter 0! Copying the solution and t_grid from the testing set!
# 16:27:57.051 - Sample:Run_Samples:182 - INFO - Searching for training parameter 1, [0.9 1.1], in the testing set.
# 16:27:57.051 - Sample:Run_Samples:182 - INFO - Searching for training parameter 1, [0.9 1.1], in the testing set.
# 16:27:57.051 - Sample:Run_Samples:187 - INFO - Train parameter 1 is test parameter 4! Copying the solution and t_grid from the testing set!
# 16:27:57.051 - Sample:Run_Samples:187 - INFO - Train parameter 1 is test parameter 4! Copying the solution and t_grid from the testing set!
# 16:27:57.052 - Sample:Run_Samples:182 - INFO - Searching for training parameter 2, [1.1 0.9], in the testing set.
# 16:27:57.052 - Sample:Run_Samples:182 - INFO - Searching for training parameter 2, [1.1 0.9], in the testing set.
# 16:27:57.052 - Sample:Run_Samples:187 - INFO - Train parameter 2 is test parameter 20! Copying the solution and t_grid from the testing set!
# 16:27:57.052 - Sample:Run_Samples:187 - INFO - Train parameter 2 is test parameter 20! Copying the solution and t_grid from the testing set!
# 16:27:57.053 - Sample:Run_Samples:182 - INFO - Searching for training parameter 3, [1.1 1.1], in the testing set.
# 16:27:57.053 - Sample:Run_Samples:182 - INFO - Searching for training parameter 3, [1.1 1.1], in the testing set.
# 16:27:57.054 - Sample:Run_Samples:187 - INFO - Train parameter 3 is test parameter 24! Copying the solution and t_grid from the testing set!
# 16:27:57.054 - Sample:Run_Samples:187 - INFO - Train parameter 3 is test parameter 24! Copying the solution and t_grid from the testing set!
# 16:27:57.055 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 16:27:57.055 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 16:27:57.056 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #0 over 5 time steps
# 16:27:57.056 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #0 over 5 time steps
# 16:27:57.063 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 16:27:57.063 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 16:27:57.063 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 16:27:57.063 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 16:27:57.064 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 16:27:57.064 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 16:27:57.070 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 16:27:57.070 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 16:27:57.072 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 16:27:57.072 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 16:27:57.073 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #2 over 6 time steps
# 16:27:57.073 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #2 over 6 time steps
# 16:27:57.078 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #2.
# 16:27:57.078 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #2.
# 16:27:57.079 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 16:27:57.079 - GPLaSDI:_rollout_setup:867 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 16:27:57.080 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #3 over 6 time steps
# 16:27:57.080 - GPLaSDI:_rollout_setup:876 - INFO - We will rollout each frame for parameter combination #3 over 6 time steps
# 16:27:57.085 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 16:27:57.085 - GPLaSDI:_rollout_setup:890 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 16:27:57.222 - GPLaSDI:train:275 - INFO - Training for 2000 epochs (starting at 0, going to 2000) with 4 parameters
# 16:27:57.222 - GPLaSDI:train:275 - INFO - Training for 2000 epochs (starting at 0, going to 2000) with 4 parameters
# 16:27:57.349 - GPLaSDI:train:715 - INFO - Iter: 00001/4000, Total: 7.264495, Recon D: 0.399164, Recon V: 0.438454, CR X: 0.442126, CR Z: 1.564351, Cons Z: 2.393587, Cons X: 0.046008, Roll D: 0.399290, Roll V: 0.439632, Roll ZD: 0.000239, Roll ZV: 0.007038, LD: 2.352795, Coef: 3813.083252, max|c|: 494.9,
# 16:27:57.349 - GPLaSDI:train:715 - INFO - Iter: 00001/4000, Total: 7.264495, Recon D: 0.399164, Recon V: 0.438454, CR X: 0.442126, CR Z: 1.564351, Cons Z: 2.393587, Cons X: 0.046008, Roll D: 0.399290, Roll V: 0.439632, Roll ZD: 0.000239, Roll ZV: 0.007038, LD: 2.352795, Coef: 3813.083252, max|c|: 494.9,
# 16:27:57.480 - GPLaSDI:train:715 - INFO - Iter: 00002/4000, Total: 9.937065, Recon D: 0.401052, Recon V: 0.455665, CR X: 0.437742, CR Z: 3.224682, Cons Z: 3.759963, Cons X: 0.031269, Roll D: 0.401062, Roll V: 0.453726, Roll ZD: 0.000364, Roll ZV: 0.026522, LD: 0.542831, Coef: 9144.404297, max|c|: 2071.8,
# 16:27:57.480 - GPLaSDI:train:715 - INFO - Iter: 00002/4000, Total: 9.937065, Recon D: 0.401052, Recon V: 0.455665, CR X: 0.437742, CR Z: 3.224682, Cons Z: 3.759963, Cons X: 0.031269, Roll D: 0.401062, Roll V: 0.453726, Roll ZD: 0.000364, Roll ZV: 0.026522, LD: 0.542831, Coef: 9144.404297, max|c|: 2071.8,
# 16:27:57.576 - GPLaSDI:train:715 - INFO - Iter: 00003/4000, Total: 7.417356, Recon D: 0.399054, Recon V: 0.439835, CR X: 0.431441, CR Z: 1.862775, Cons Z: 2.356260, Cons X: 0.025403, Roll D: 0.399186, Roll V: 0.440942, Roll ZD: 0.000235, Roll ZV: 0.002706, LD: 2.333917, Coef: 3140.941650, max|c|: 625.1,
# 16:27:57.576 - GPLaSDI:train:715 - INFO - Iter: 00003/4000, Total: 7.417356, Recon D: 0.399054, Recon V: 0.439835, CR X: 0.431441, CR Z: 1.862775, Cons Z: 2.356260, Cons X: 0.025403, Roll D: 0.399186, Roll V: 0.440942, Roll ZD: 0.000235, Roll ZV: 0.002706, LD: 2.333917, Coef: 3140.941650, max|c|: 625.1,
# 16:27:57.674 - GPLaSDI:train:715 - INFO - Iter: 00004/4000, Total: 4.448925, Recon D: 0.391419, Recon V: 0.432298, CR X: 0.435761, CR Z: 0.637814, Cons Z: 1.014140, Cons X: 0.023786, Roll D: 0.391689, Roll V: 0.433400, Roll ZD: 0.000100, Roll ZV: 0.003128, LD: 1.555664, Coef: 3217.157959, max|c|: 382.8,
# 16:27:57.674 - GPLaSDI:train:715 - INFO - Iter: 00004/4000, Total: 4.448925, Recon D: 0.391419, Recon V: 0.432298, CR X: 0.435761, CR Z: 0.637814, Cons Z: 1.014140, Cons X: 0.023786, Roll D: 0.391689, Roll V: 0.433400, Roll ZD: 0.000100, Roll ZV: 0.003128, LD: 1.555664, Coef: 3217.157959, max|c|: 382.8,
# 16:27:57.767 - GPLaSDI:train:715 - INFO - Iter: 00005/4000, Total: 5.142640, Recon D: 0.377570, Recon V: 0.421352, CR X: 0.438090, CR Z: 1.067832, Cons Z: 1.584363, Cons X: 0.024404, Roll D: 0.377749, Roll V: 0.422258, Roll ZD: 0.000156, Roll ZV: 0.003490, LD: 0.887311, Coef: 3835.462402, max|c|: 573.9,
# 16:27:57.767 - GPLaSDI:train:715 - INFO - Iter: 00005/4000, Total: 5.142640, Recon D: 0.377570, Recon V: 0.421352, CR X: 0.438090, CR Z: 1.067832, Cons Z: 1.584363, Cons X: 0.024404, Roll D: 0.377749, Roll V: 0.422258, Roll ZD: 0.000156, Roll ZV: 0.003490, LD: 0.887311, Coef: 3835.462402, max|c|: 573.9,
# 16:27:57.861 - GPLaSDI:train:715 - INFO - Iter: 00006/4000, Total: 5.351387, Recon D: 0.359637, Recon V: 0.409894, CR X: 0.437205, CR Z: 1.434020, Cons Z: 1.976698, Cons X: 0.025334, Roll D: 0.359691, Roll V: 0.410902, Roll ZD: 0.000195, Roll ZV: 0.003671, LD: 0.305675, Coef: 1685.327515, max|c|: 215.9,
# 16:27:57.861 - GPLaSDI:train:715 - INFO - Iter: 00006/4000, Total: 5.351387, Recon D: 0.359637, Recon V: 0.409894, CR X: 0.437205, CR Z: 1.434020, Cons Z: 1.976698, Cons X: 0.025334, Roll D: 0.359691, Roll V: 0.410902, Roll ZD: 0.000195, Roll ZV: 0.003671, LD: 0.305675, Coef: 1685.327515, max|c|: 215.9,
# 16:27:57.960 - GPLaSDI:train:715 - INFO - Iter: 00007/4000, Total: 4.720033, Recon D: 0.338572, Recon V: 0.395005, CR X: 0.433393, CR Z: 1.200658, Cons Z: 1.667135, Cons X: 0.024199, Roll D: 0.338568, Roll V: 0.395944, Roll ZD: 0.000164, Roll ZV: 0.004107, LD: 0.236860, Coef: 1732.495361, max|c|: 241.6,
# 16:27:57.960 - GPLaSDI:train:715 - INFO - Iter: 00007/4000, Total: 4.720033, Recon D: 0.338572, Recon V: 0.395005, CR X: 0.433393, CR Z: 1.200658, Cons Z: 1.667135, Cons X: 0.024199, Roll D: 0.338568, Roll V: 0.395944, Roll ZD: 0.000164, Roll ZV: 0.004107, LD: 0.236860, Coef: 1732.495361, max|c|: 241.6,
# 16:27:58.060 - GPLaSDI:train:715 - INFO - Iter: 00008/4000, Total: 3.506377, Recon D: 0.315093, Recon V: 0.377495, CR X: 0.426961, CR Z: 0.681267, Cons Z: 1.036988, Cons X: 0.022753, Roll D: 0.315113, Roll V: 0.378363, Roll ZD: 0.000101, Roll ZV: 0.004347, LD: 0.222256, Coef: 1857.304199, max|c|: 254.2,
# 16:27:58.060 - GPLaSDI:train:715 - INFO - Iter: 00008/4000, Total: 3.506377, Recon D: 0.315093, Recon V: 0.377495, CR X: 0.426961, CR Z: 0.681267, Cons Z: 1.036988, Cons X: 0.022753, Roll D: 0.315113, Roll V: 0.378363, Roll ZD: 0.000101, Roll ZV: 0.004347, LD: 0.222256, Coef: 1857.304199, max|c|: 254.2,
# 16:27:58.160 - GPLaSDI:train:715 - INFO - Iter: 00009/4000, Total: 2.838772, Recon D: 0.289603, Recon V: 0.360119, CR X: 0.421004, CR Z: 0.406768, Cons Z: 0.688487, Cons X: 0.023238, Roll D: 0.289688, Roll V: 0.360909, Roll ZD: 0.000067, Roll ZV: 0.004539, LD: 0.205658, Coef: 2191.227295, max|c|: 284.1,
# 16:27:58.160 - GPLaSDI:train:715 - INFO - Iter: 00009/4000, Total: 2.838772, Recon D: 0.289603, Recon V: 0.360119, CR X: 0.421004, CR Z: 0.406768, Cons Z: 0.688487, Cons X: 0.023238, Roll D: 0.289688, Roll V: 0.360909, Roll ZD: 0.000067, Roll ZV: 0.004539, LD: 0.205658, Coef: 2191.227295, max|c|: 284.1,
# 16:27:58.254 - GPLaSDI:train:715 - INFO - Iter: 00010/4000, Total: 2.846552, Recon D: 0.262247, Recon V: 0.343821, CR X: 0.417446, CR Z: 0.438785, Cons Z: 0.701130, Cons X: 0.025784, Roll D: 0.262389, Roll V: 0.344545, Roll ZD: 0.000069, Roll ZV: 0.004730, LD: 0.186234, Coef: 2583.559570, max|c|: 389.9,
# 16:27:58.254 - GPLaSDI:train:715 - INFO - Iter: 00010/4000, Total: 2.846552, Recon D: 0.262247, Recon V: 0.343821, CR X: 0.417446, CR Z: 0.438785, Cons Z: 0.701130, Cons X: 0.025784, Roll D: 0.262389, Roll V: 0.344545, Roll ZD: 0.000069, Roll ZV: 0.004730, LD: 0.186234, Coef: 2583.559570, max|c|: 389.9,
# 16:27:58.345 - GPLaSDI:train:715 - INFO - Iter: 00011/4000, Total: 2.913616, Recon D: 0.233262, Recon V: 0.328015, CR X: 0.416074, CR Z: 0.525805, Cons Z: 0.796533, Cons X: 0.029412, Roll D: 0.233424, Roll V: 0.328715, Roll ZD: 0.000079, Roll ZV: 0.004371, LD: 0.157139, Coef: 2226.509033, max|c|: 355.8,
# 16:27:58.345 - GPLaSDI:train:715 - INFO - Iter: 00011/4000, Total: 2.913616, Recon D: 0.233262, Recon V: 0.328015, CR X: 0.416074, CR Z: 0.525805, Cons Z: 0.796533, Cons X: 0.029412, Roll D: 0.233424, Roll V: 0.328715, Roll ZD: 0.000079, Roll ZV: 0.004371, LD: 0.157139, Coef: 2226.509033, max|c|: 355.8,
# 16:27:58.446 - GPLaSDI:train:715 - INFO - Iter: 00012/4000, Total: 2.830145, Recon D: 0.203406, Recon V: 0.312326, CR X: 0.415706, CR Z: 0.543759, Cons Z: 0.823951, Cons X: 0.033400, Roll D: 0.203538, Roll V: 0.313041, Roll ZD: 0.000082, Roll ZV: 0.003850, LD: 0.124635, Coef: 1750.233154, max|c|: 243.6,
# 16:27:58.446 - GPLaSDI:train:715 - INFO - Iter: 00012/4000, Total: 2.830145, Recon D: 0.203406, Recon V: 0.312326, CR X: 0.415706, CR Z: 0.543759, Cons Z: 0.823951, Cons X: 0.033400, Roll D: 0.203538, Roll V: 0.313041, Roll ZD: 0.000082, Roll ZV: 0.003850, LD: 0.124635, Coef: 1750.233154, max|c|: 243.6,
# 16:27:58.559 - GPLaSDI:train:715 - INFO - Iter: 00013/4000, Total: 2.629863, Recon D: 0.174043, Recon V: 0.296500, CR X: 0.415164, CR Z: 0.498526, Cons Z: 0.776917, Cons X: 0.037464, Roll D: 0.174092, Roll V: 0.297267, Roll ZD: 0.000077, Roll ZV: 0.003404, LD: 0.096536, Coef: 1455.614258, max|c|: 166.5,
# 16:27:58.559 - GPLaSDI:train:715 - INFO - Iter: 00013/4000, Total: 2.629863, Recon D: 0.174043, Recon V: 0.296500, CR X: 0.415164, CR Z: 0.498526, Cons Z: 0.776917, Cons X: 0.037464, Roll D: 0.174092, Roll V: 0.297267, Roll ZD: 0.000077, Roll ZV: 0.003404, LD: 0.096536, Coef: 1455.614258, max|c|: 166.5,
# 16:27:58.656 - GPLaSDI:train:715 - INFO - Iter: 00014/4000, Total: 2.334738, Recon D: 0.147047, Recon V: 0.279962, CR X: 0.413727, CR Z: 0.402019, Cons Z: 0.662228, Cons X: 0.041890, Roll D: 0.146972, Roll V: 0.280811, Roll ZD: 0.000066, Roll ZV: 0.003048, LD: 0.084599, Coef: 1301.157471, max|c|: 139.1,
# 16:27:58.656 - GPLaSDI:train:715 - INFO - Iter: 00014/4000, Total: 2.334738, Recon D: 0.147047, Recon V: 0.279962, CR X: 0.413727, CR Z: 0.402019, Cons Z: 0.662228, Cons X: 0.041890, Roll D: 0.146972, Roll V: 0.280811, Roll ZD: 0.000066, Roll ZV: 0.003048, LD: 0.084599, Coef: 1301.157471, max|c|: 139.1,
# 16:27:58.755 - GPLaSDI:train:715 - INFO - Iter: 00015/4000, Total: 1.985286, Recon D: 0.124426, Recon V: 0.262452, CR X: 0.411335, CR Z: 0.276832, Cons Z: 0.504768, Cons X: 0.047458, Roll D: 0.124201, Roll V: 0.263365, Roll ZD: 0.000050, Roll ZV: 0.002746, LD: 0.077985, Coef: 1238.405884, max|c|: 139.7,
# 16:27:58.755 - GPLaSDI:train:715 - INFO - Iter: 00015/4000, Total: 1.985286, Recon D: 0.124426, Recon V: 0.262452, CR X: 0.411335, CR Z: 0.276832, Cons Z: 0.504768, Cons X: 0.047458, Roll D: 0.124201, Roll V: 0.263365, Roll ZD: 0.000050, Roll ZV: 0.002746, LD: 0.077985, Coef: 1238.405884, max|c|: 139.7,
# 16:27:58.852 - GPLaSDI:train:715 - INFO - Iter: 00016/4000, Total: 1.701056, Recon D: 0.107707, Recon V: 0.244563, CR X: 0.408350, CR Z: 0.177630, Cons Z: 0.367757, Cons X: 0.054845, Roll D: 0.107323, Roll V: 0.245464, Roll ZD: 0.000036, Roll ZV: 0.002472, LD: 0.079807, Coef: 1226.515259, max|c|: 138.1,
# 16:27:58.852 - GPLaSDI:train:715 - INFO - Iter: 00016/4000, Total: 1.701056, Recon D: 0.107707, Recon V: 0.244563, CR X: 0.408350, CR Z: 0.177630, Cons Z: 0.367757, Cons X: 0.054845, Roll D: 0.107323, Roll V: 0.245464, Roll ZD: 0.000036, Roll ZV: 0.002472, LD: 0.079807, Coef: 1226.515259, max|c|: 138.1,
# 16:27:58.948 - GPLaSDI:train:715 - INFO - Iter: 00017/4000, Total: 1.577218, Recon D: 0.097138, Recon V: 0.227302, CR X: 0.405174, CR Z: 0.149200, Cons Z: 0.305799, Cons X: 0.064071, Roll D: 0.096603, Roll V: 0.228075, Roll ZD: 0.000030, Roll ZV: 0.002230, LD: 0.081321, Coef: 1244.044556, max|c|: 135.6,
# 16:27:58.948 - GPLaSDI:train:715 - INFO - Iter: 00017/4000, Total: 1.577218, Recon D: 0.097138, Recon V: 0.227302, CR X: 0.405174, CR Z: 0.149200, Cons Z: 0.305799, Cons X: 0.064071, Roll D: 0.096603, Roll V: 0.228075, Roll ZD: 0.000030, Roll ZV: 0.002230, LD: 0.081321, Coef: 1244.044556, max|c|: 135.6,
# 16:27:59.034 - GPLaSDI:train:715 - INFO - Iter: 00018/4000, Total: 1.586980, Recon D: 0.091282, Recon V: 0.211211, CR X: 0.402086, CR Z: 0.178237, Cons Z: 0.311305, Cons X: 0.074539, Roll D: 0.090624, Roll V: 0.211787, Roll ZD: 0.000031, Roll ZV: 0.002004, LD: 0.079966, Coef: 1261.146606, max|c|: 132.9,
# 16:27:59.034 - GPLaSDI:train:715 - INFO - Iter: 00018/4000, Total: 1.586980, Recon D: 0.091282, Recon V: 0.211211, CR X: 0.402086, CR Z: 0.178237, Cons Z: 0.311305, Cons X: 0.074539, Roll D: 0.090624, Roll V: 0.211787, Roll ZD: 0.000031, Roll ZV: 0.002004, LD: 0.079966, Coef: 1261.146606, max|c|: 132.9,
# 16:27:59.119 - GPLaSDI:train:715 - INFO - Iter: 00019/4000, Total: 1.620194, Recon D: 0.087566, Recon V: 0.196264, CR X: 0.399316, CR Z: 0.211859, Cons Z: 0.331512, Cons X: 0.085461, Roll D: 0.086817, Roll V: 0.196673, Roll ZD: 0.000033, Roll ZV: 0.001788, LD: 0.081560, Coef: 1247.809570, max|c|: 131.4,
# 16:27:59.119 - GPLaSDI:train:715 - INFO - Iter: 00019/4000, Total: 1.620194, Recon D: 0.087566, Recon V: 0.196264, CR X: 0.399316, CR Z: 0.211859, Cons Z: 0.331512, Cons X: 0.085461, Roll D: 0.086817, Roll V: 0.196673, Roll ZD: 0.000033, Roll ZV: 0.001788, LD: 0.081560, Coef: 1247.809570, max|c|: 131.4,
# 16:27:59.204 - GPLaSDI:train:715 - INFO - Iter: 00020/4000, Total: 1.597163, Recon D: 0.083661, Recon V: 0.182329, CR X: 0.397054, CR Z: 0.217276, Cons Z: 0.329897, Cons X: 0.096248, Roll D: 0.082847, Roll V: 0.182696, Roll ZD: 0.000033, Roll ZV: 0.001580, LD: 0.078636, Coef: 1178.019775, max|c|: 130.4,
# 16:27:59.204 - GPLaSDI:train:715 - INFO - Iter: 00020/4000, Total: 1.597163, Recon D: 0.083661, Recon V: 0.182329, CR X: 0.397054, CR Z: 0.217276, Cons Z: 0.329897, Cons X: 0.096248, Roll D: 0.082847, Roll V: 0.182696, Roll ZD: 0.000033, Roll ZV: 0.001580, LD: 0.078636, Coef: 1178.019775, max|c|: 130.4,
# 16:27:59.297 - GPLaSDI:train:715 - INFO - Iter: 00021/4000, Total: 1.528150, Recon D: 0.078476, Recon V: 0.169163, CR X: 0.395306, CR Z: 0.199995, Cons Z: 0.307110, Cons X: 0.106824, Roll D: 0.077606, Roll V: 0.169618, Roll ZD: 0.000030, Roll ZV: 0.001386, LD: 0.077428, Coef: 1082.403809, max|c|: 130.1,
# 16:27:59.297 - GPLaSDI:train:715 - INFO - Iter: 00021/4000, Total: 1.528150, Recon D: 0.078476, Recon V: 0.169163, CR X: 0.395306, CR Z: 0.199995, Cons Z: 0.307110, Cons X: 0.106824, Roll D: 0.077606, Roll V: 0.169618, Roll ZD: 0.000030, Roll ZV: 0.001386, LD: 0.077428, Coef: 1082.403809, max|c|: 130.1,
# 16:27:59.388 - GPLaSDI:train:715 - INFO - Iter: 00022/4000, Total: 1.441549, Recon D: 0.072271, Recon V: 0.156227, CR X: 0.393935, CR Z: 0.173949, Cons Z: 0.273279, Cons X: 0.117669, Roll D: 0.071347, Roll V: 0.156805, Roll ZD: 0.000027, Roll ZV: 0.001215, LD: 0.077531, Coef: 1007.564148, max|c|: 129.8,
# 16:27:59.388 - GPLaSDI:train:715 - INFO - Iter: 00022/4000, Total: 1.441549, Recon D: 0.072271, Recon V: 0.156227, CR X: 0.393935, CR Z: 0.173949, Cons Z: 0.273279, Cons X: 0.117669, Roll D: 0.071347, Roll V: 0.156805, Roll ZD: 0.000027, Roll ZV: 0.001215, LD: 0.077531, Coef: 1007.564148, max|c|: 129.8,
# 16:27:59.483 - GPLaSDI:train:715 - INFO - Iter: 00023/4000, Total: 1.343365, Recon D: 0.066033, Recon V: 0.143110, CR X: 0.392850, CR Z: 0.141489, Cons Z: 0.229044, Cons X: 0.129295, Roll D: 0.065059, Roll V: 0.143753, Roll ZD: 0.000023, Roll ZV: 0.001071, LD: 0.077420, Coef: 978.806030, max|c|: 128.6,
# 16:27:59.483 - GPLaSDI:train:715 - INFO - Iter: 00023/4000, Total: 1.343365, Recon D: 0.066033, Recon V: 0.143110, CR X: 0.392850, CR Z: 0.141489, Cons Z: 0.229044, Cons X: 0.129295, Roll D: 0.065059, Roll V: 0.143753, Roll ZD: 0.000023, Roll ZV: 0.001071, LD: 0.077420, Coef: 978.806030, max|c|: 128.6,
# 16:27:59.577 - GPLaSDI:train:715 - INFO - Iter: 00024/4000, Total: 1.237981, Recon D: 0.060822, Recon V: 0.130407, CR X: 0.392148, CR Z: 0.104262, Cons Z: 0.176960, Cons X: 0.141100, Roll D: 0.059815, Roll V: 0.131012, Roll ZD: 0.000017, Roll ZV: 0.000946, LD: 0.074796, Coef: 989.885742, max|c|: 126.5,
# 16:27:59.577 - GPLaSDI:train:715 - INFO - Iter: 00024/4000, Total: 1.237981, Recon D: 0.060822, Recon V: 0.130407, CR X: 0.392148, CR Z: 0.104262, Cons Z: 0.176960, Cons X: 0.141100, Roll D: 0.059815, Roll V: 0.131012, Roll ZD: 0.000017, Roll ZV: 0.000946, LD: 0.074796, Coef: 989.885742, max|c|: 126.5,
# 16:27:59.669 - GPLaSDI:train:715 - INFO - Iter: 00025/4000, Total: 1.151336, Recon D: 0.057307, Recon V: 0.119692, CR X: 0.391982, CR Z: 0.075242, Cons Z: 0.132738, Cons X: 0.150764, Roll D: 0.056293, Roll V: 0.120181, Roll ZD: 0.000013, Roll ZV: 0.000840, LD: 0.068964, Coef: 1004.654358, max|c|: 123.1,
# 16:27:59.669 - GPLaSDI:train:715 - INFO - Iter: 00025/4000, Total: 1.151336, Recon D: 0.057307, Recon V: 0.119692, CR X: 0.391982, CR Z: 0.075242, Cons Z: 0.132738, Cons X: 0.150764, Roll D: 0.056293, Roll V: 0.120181, Roll ZD: 0.000013, Roll ZV: 0.000840, LD: 0.068964, Coef: 1004.654358, max|c|: 123.1,
# 16:27:59.759 - GPLaSDI:train:715 - INFO - Iter: 00026/4000, Total: 1.114084, Recon D: 0.055578, Recon V: 0.112502, CR X: 0.392301, CR Z: 0.068913, Cons Z: 0.113650, Cons X: 0.155164, Roll D: 0.054584, Roll V: 0.112852, Roll ZD: 0.000011, Roll ZV: 0.000746, LD: 0.062408, Coef: 1006.745728, max|c|: 118.2,
# 16:27:59.759 - GPLaSDI:train:715 - INFO - Iter: 00026/4000, Total: 1.114084, Recon D: 0.055578, Recon V: 0.112502, CR X: 0.392301, CR Z: 0.068913, Cons Z: 0.113650, Cons X: 0.155164, Roll D: 0.054584, Roll V: 0.112852, Roll ZD: 0.000011, Roll ZV: 0.000746, LD: 0.062408, Coef: 1006.745728, max|c|: 118.2,
# 16:27:59.847 - GPLaSDI:train:715 - INFO - Iter: 00027/4000, Total: 1.122190, Recon D: 0.055198, Recon V: 0.109479, CR X: 0.392686, CR Z: 0.083862, Cons Z: 0.119679, Cons X: 0.152374, Roll D: 0.054242, Roll V: 0.109720, Roll ZD: 0.000012, Roll ZV: 0.000670, LD: 0.055117, Coef: 990.307678, max|c|: 129.6,
# 16:27:59.847 - GPLaSDI:train:715 - INFO - Iter: 00027/4000, Total: 1.122190, Recon D: 0.055198, Recon V: 0.109479, CR X: 0.392686, CR Z: 0.083862, Cons Z: 0.119679, Cons X: 0.152374, Roll D: 0.054242, Roll V: 0.109720, Roll ZD: 0.000012, Roll ZV: 0.000670, LD: 0.055117, Coef: 990.307678, max|c|: 129.6,
# 16:27:59.936 - GPLaSDI:train:715 - INFO - Iter: 00028/4000, Total: 1.143103, Recon D: 0.055464, Recon V: 0.110215, CR X: 0.392379, CR Z: 0.102325, Cons Z: 0.132659, Cons X: 0.143116, Roll D: 0.054552, Roll V: 0.110398, Roll ZD: 0.000013, Roll ZV: 0.000605, LD: 0.049201, Coef: 995.608032, max|c|: 136.4,
# 16:27:59.936 - GPLaSDI:train:715 - INFO - Iter: 00028/4000, Total: 1.143103, Recon D: 0.055464, Recon V: 0.110215, CR X: 0.392379, CR Z: 0.102325, Cons Z: 0.132659, Cons X: 0.143116, Roll D: 0.054552, Roll V: 0.110398, Roll ZD: 0.000013, Roll ZV: 0.000605, LD: 0.049201, Coef: 995.608032, max|c|: 136.4,
# 16:28:00.023 - GPLaSDI:train:715 - INFO - Iter: 00029/4000, Total: 1.138615, Recon D: 0.055732, Recon V: 0.113432, CR X: 0.390532, CR Z: 0.108113, Cons Z: 0.134958, Cons X: 0.130457, Roll D: 0.054857, Roll V: 0.113629, Roll ZD: 0.000013, Roll ZV: 0.000551, LD: 0.047178, Coef: 972.773071, max|c|: 140.6,
# 16:28:00.023 - GPLaSDI:train:715 - INFO - Iter: 00029/4000, Total: 1.138615, Recon D: 0.055732, Recon V: 0.113432, CR X: 0.390532, CR Z: 0.108113, Cons Z: 0.134958, Cons X: 0.130457, Roll D: 0.054857, Roll V: 0.113629, Roll ZD: 0.000013, Roll ZV: 0.000551, LD: 0.047178, Coef: 972.773071, max|c|: 140.6,
# 16:28:00.112 - GPLaSDI:train:715 - INFO - Iter: 00030/4000, Total: 1.105997, Recon D: 0.055593, Recon V: 0.117314, CR X: 0.386479, CR Z: 0.099785, Cons Z: 0.123684, Cons X: 0.118108, Roll D: 0.054743, Roll V: 0.117578, Roll ZD: 0.000012, Roll ZV: 0.000503, LD: 0.045214, Coef: 960.092651, max|c|: 139.6,
# 16:28:00.112 - GPLaSDI:train:715 - INFO - Iter: 00030/4000, Total: 1.105997, Recon D: 0.055593, Recon V: 0.117314, CR X: 0.386479, CR Z: 0.099785, Cons Z: 0.123684, Cons X: 0.118108, Roll D: 0.054743, Roll V: 0.117578, Roll ZD: 0.000012, Roll ZV: 0.000503, LD: 0.045214, Coef: 960.092651, max|c|: 139.6,
# 16:28:00.202 - GPLaSDI:train:715 - INFO - Iter: 00031/4000, Total: 1.060948, Recon D: 0.054860, Recon V: 0.120006, CR X: 0.379892, CR Z: 0.085398, Cons Z: 0.106003, Cons X: 0.108813, Roll D: 0.054019, Roll V: 0.120353, Roll ZD: 0.000010, Roll ZV: 0.000463, LD: 0.045496, Coef: 958.055054, max|c|: 134.6,
# 16:28:00.202 - GPLaSDI:train:715 - INFO - Iter: 00031/4000, Total: 1.060948, Recon D: 0.054860, Recon V: 0.120006, CR X: 0.379892, CR Z: 0.085398, Cons Z: 0.106003, Cons X: 0.108813, Roll D: 0.054019, Roll V: 0.120353, Roll ZD: 0.000010, Roll ZV: 0.000463, LD: 0.045496, Coef: 958.055054, max|c|: 134.6,
# 16:28:00.298 - GPLaSDI:train:715 - INFO - Iter: 00032/4000, Total: 1.008799, Recon D: 0.053569, Recon V: 0.120232, CR X: 0.370805, CR Z: 0.071267, Cons Z: 0.087954, Cons X: 0.103653, Roll D: 0.052727, Roll V: 0.120622, Roll ZD: 0.000009, Roll ZV: 0.000429, LD: 0.044567, Coef: 921.433716, max|c|: 128.4,
# 16:28:00.298 - GPLaSDI:train:715 - INFO - Iter: 00032/4000, Total: 1.008799, Recon D: 0.053569, Recon V: 0.120232, CR X: 0.370805, CR Z: 0.071267, Cons Z: 0.087954, Cons X: 0.103653, Roll D: 0.052727, Roll V: 0.120622, Roll ZD: 0.000009, Roll ZV: 0.000429, LD: 0.044567, Coef: 921.433716, max|c|: 128.4,
# 16:28:00.417 - GPLaSDI:train:715 - INFO - Iter: 00033/4000, Total: 0.958416, Recon D: 0.051915, Recon V: 0.117806, CR X: 0.359601, CR Z: 0.059141, Cons Z: 0.071603, Cons X: 0.102083, Roll D: 0.051068, Roll V: 0.118172, Roll ZD: 0.000007, Roll ZV: 0.000402, LD: 0.047226, Coef: 878.301025, max|c|: 121.7,
# 16:28:00.417 - GPLaSDI:train:715 - INFO - Iter: 00033/4000, Total: 0.958416, Recon D: 0.051915, Recon V: 0.117806, CR X: 0.359601, CR Z: 0.059141, Cons Z: 0.071603, Cons X: 0.102083, Roll D: 0.051068, Roll V: 0.118172, Roll ZD: 0.000007, Roll ZV: 0.000402, LD: 0.047226, Coef: 878.301025, max|c|: 121.7,
# 16:28:00.512 - GPLaSDI:train:715 - INFO - Iter: 00034/4000, Total: 0.911417, Recon D: 0.050092, Recon V: 0.113624, CR X: 0.346999, CR Z: 0.050740, Cons Z: 0.059385, Cons X: 0.102351, Roll D: 0.049239, Roll V: 0.113919, Roll ZD: 0.000006, Roll ZV: 0.000379, LD: 0.046506, Coef: 832.011658, max|c|: 112.2,
# 16:28:00.512 - GPLaSDI:train:715 - INFO - Iter: 00034/4000, Total: 0.911417, Recon D: 0.050092, Recon V: 0.113624, CR X: 0.346999, CR Z: 0.050740, Cons Z: 0.059385, Cons X: 0.102351, Roll D: 0.049239, Roll V: 0.113919, Roll ZD: 0.000006, Roll ZV: 0.000379, LD: 0.046506, Coef: 832.011658, max|c|: 112.2,
# 16:28:00.610 - GPLaSDI:train:715 - INFO - Iter: 00035/4000, Total: 0.877430, Recon D: 0.048250, Recon V: 0.109087, CR X: 0.333855, CR Z: 0.048527, Cons Z: 0.054482, Cons X: 0.102195, Roll D: 0.047395, Roll V: 0.109298, Roll ZD: 0.000005, Roll ZV: 0.000362, LD: 0.046323, Coef: 793.415894, max|c|: 102.3,
# 16:28:00.610 - GPLaSDI:train:715 - INFO - Iter: 00035/4000, Total: 0.877430, Recon D: 0.048250, Recon V: 0.109087, CR X: 0.333855, CR Z: 0.048527, Cons Z: 0.054482, Cons X: 0.102195, Roll D: 0.047395, Roll V: 0.109298, Roll ZD: 0.000005, Roll ZV: 0.000362, LD: 0.046323, Coef: 793.415894, max|c|: 102.3,
# 16:28:00.720 - GPLaSDI:train:715 - INFO - Iter: 00036/4000, Total: 0.854155, Recon D: 0.046441, Recon V: 0.105334, CR X: 0.320875, CR Z: 0.051821, Cons Z: 0.056579, Cons X: 0.099783, Roll D: 0.045591, Roll V: 0.105470, Roll ZD: 0.000005, Roll ZV: 0.000347, LD: 0.044548, Coef: 753.422485, max|c|: 99.0,
# 16:28:00.720 - GPLaSDI:train:715 - INFO - Iter: 00036/4000, Total: 0.854155, Recon D: 0.046441, Recon V: 0.105334, CR X: 0.320875, CR Z: 0.051821, Cons Z: 0.056579, Cons X: 0.099783, Roll D: 0.045591, Roll V: 0.105470, Roll ZD: 0.000005, Roll ZV: 0.000347, LD: 0.044548, Coef: 753.422485, max|c|: 99.0,
# 16:28:00.818 - GPLaSDI:train:715 - INFO - Iter: 00037/4000, Total: 0.834472, Recon D: 0.044599, Recon V: 0.102740, CR X: 0.308331, CR Z: 0.055536, Cons Z: 0.060432, Cons X: 0.094508, Roll D: 0.043763, Roll V: 0.102825, Roll ZD: 0.000006, Roll ZV: 0.000334, LD: 0.043247, Coef: 732.387939, max|c|: 100.0,
# 16:28:00.818 - GPLaSDI:train:715 - INFO - Iter: 00037/4000, Total: 0.834472, Recon D: 0.044599, Recon V: 0.102740, CR X: 0.308331, CR Z: 0.055536, Cons Z: 0.060432, Cons X: 0.094508, Roll D: 0.043763, Roll V: 0.102825, Roll ZD: 0.000006, Roll ZV: 0.000334, LD: 0.043247, Coef: 732.387939, max|c|: 100.0,
# 16:28:00.911 - GPLaSDI:train:715 - INFO - Iter: 00038/4000, Total: 0.804685, Recon D: 0.042607, Recon V: 0.100826, CR X: 0.295980, CR Z: 0.054776, Cons Z: 0.060564, Cons X: 0.087132, Roll D: 0.041793, Roll V: 0.100883, Roll ZD: 0.000006, Roll ZV: 0.000322, LD: 0.040927, Coef: 708.353821, max|c|: 100.2,
# 16:28:00.911 - GPLaSDI:train:715 - INFO - Iter: 00038/4000, Total: 0.804685, Recon D: 0.042607, Recon V: 0.100826, CR X: 0.295980, CR Z: 0.054776, Cons Z: 0.060564, Cons X: 0.087132, Roll D: 0.041793, Roll V: 0.100883, Roll ZD: 0.000006, Roll ZV: 0.000322, LD: 0.040927, Coef: 708.353821, max|c|: 100.2,
# 16:28:01.007 - GPLaSDI:train:715 - INFO - Iter: 00039/4000, Total: 0.763294, Recon D: 0.040384, Recon V: 0.098482, CR X: 0.283033, CR Z: 0.049564, Cons Z: 0.056278, Cons X: 0.079242, Roll D: 0.039604, Roll V: 0.098529, Roll ZD: 0.000005, Roll ZV: 0.000311, LD: 0.039803, Coef: 671.839233, max|c|: 99.9,
# 16:28:01.007 - GPLaSDI:train:715 - INFO - Iter: 00039/4000, Total: 0.763294, Recon D: 0.040384, Recon V: 0.098482, CR X: 0.283033, CR Z: 0.049564, Cons Z: 0.056278, Cons X: 0.079242, Roll D: 0.039604, Roll V: 0.098529, Roll ZD: 0.000005, Roll ZV: 0.000311, LD: 0.039803, Coef: 671.839233, max|c|: 99.9,
# 16:28:01.098 - GPLaSDI:train:715 - INFO - Iter: 00040/4000, Total: 0.718595, Recon D: 0.037901, Recon V: 0.094535, CR X: 0.268337, CR Z: 0.043491, Cons Z: 0.050513, Cons X: 0.072288, Roll D: 0.037163, Roll V: 0.094575, Roll ZD: 0.000005, Roll ZV: 0.000298, LD: 0.038069, Coef: 664.759216, max|c|: 98.6,
# 16:28:01.098 - GPLaSDI:train:715 - INFO - Iter: 00040/4000, Total: 0.718595, Recon D: 0.037901, Recon V: 0.094535, CR X: 0.268337, CR Z: 0.043491, Cons Z: 0.050513, Cons X: 0.072288, Roll D: 0.037163, Roll V: 0.094575, Roll ZD: 0.000005, Roll ZV: 0.000298, LD: 0.038069, Coef: 664.759216, max|c|: 98.6,
# 16:28:01.190 - GPLaSDI:train:715 - INFO - Iter: 00041/4000, Total: 0.670582, Recon D: 0.035185, Recon V: 0.088411, CR X: 0.250830, CR Z: 0.039266, Cons Z: 0.045508, Cons X: 0.066891, Roll D: 0.034500, Roll V: 0.088427, Roll ZD: 0.000004, Roll ZV: 0.000287, LD: 0.036184, Coef: 647.904419, max|c|: 97.3,
# 16:28:01.190 - GPLaSDI:train:715 - INFO - Iter: 00041/4000, Total: 0.670582, Recon D: 0.035185, Recon V: 0.088411, CR X: 0.250830, CR Z: 0.039266, Cons Z: 0.045508, Cons X: 0.066891, Roll D: 0.034500, Roll V: 0.088427, Roll ZD: 0.000004, Roll ZV: 0.000287, LD: 0.036184, Coef: 647.904419, max|c|: 97.3,
# 16:28:01.280 - GPLaSDI:train:715 - INFO - Iter: 00042/4000, Total: 0.621756, Recon D: 0.032307, Recon V: 0.080563, CR X: 0.230035, CR Z: 0.037219, Cons Z: 0.041537, Cons X: 0.062637, Roll D: 0.031683, Roll V: 0.080542, Roll ZD: 0.000004, Roll ZV: 0.000275, LD: 0.034914, Coef: 637.497803, max|c|: 94.6,
# 16:28:01.280 - GPLaSDI:train:715 - INFO - Iter: 00042/4000, Total: 0.621756, Recon D: 0.032307, Recon V: 0.080563, CR X: 0.230035, CR Z: 0.037219, Cons Z: 0.041537, Cons X: 0.062637, Roll D: 0.031683, Roll V: 0.080542, Roll ZD: 0.000004, Roll ZV: 0.000275, LD: 0.034914, Coef: 637.497803, max|c|: 94.6,
# 16:28:01.374 - GPLaSDI:train:715 - INFO - Iter: 00043/4000, Total: 0.572755, Recon D: 0.029344, Recon V: 0.072267, CR X: 0.206362, CR Z: 0.037065, Cons Z: 0.038724, Cons X: 0.058330, Roll D: 0.028789, Roll V: 0.072194, Roll ZD: 0.000004, Roll ZV: 0.000264, LD: 0.033854, Coef: 631.115051, max|c|: 91.7,
# 16:28:01.374 - GPLaSDI:train:715 - INFO - Iter: 00043/4000, Total: 0.572755, Recon D: 0.029344, Recon V: 0.072267, CR X: 0.206362, CR Z: 0.037065, Cons Z: 0.038724, Cons X: 0.058330, Roll D: 0.028789, Roll V: 0.072194, Roll ZD: 0.000004, Roll ZV: 0.000264, LD: 0.033854, Coef: 631.115051, max|c|: 91.7,
# 16:28:01.469 - GPLaSDI:train:715 - INFO - Iter: 00044/4000, Total: 0.524931, Recon D: 0.026378, Recon V: 0.064880, CR X: 0.181106, CR Z: 0.038976, Cons Z: 0.037951, Cons X: 0.052633, Roll D: 0.025898, Roll V: 0.064756, Roll ZD: 0.000004, Roll ZV: 0.000254, LD: 0.032256, Coef: 614.241333, max|c|: 88.5,
# 16:28:01.469 - GPLaSDI:train:715 - INFO - Iter: 00044/4000, Total: 0.524931, Recon D: 0.026378, Recon V: 0.064880, CR X: 0.181106, CR Z: 0.038976, Cons Z: 0.037951, Cons X: 0.052633, Roll D: 0.025898, Roll V: 0.064756, Roll ZD: 0.000004, Roll ZV: 0.000254, LD: 0.032256, Coef: 614.241333, max|c|: 88.5,
# 16:28:01.569 - GPLaSDI:train:715 - INFO - Iter: 00045/4000, Total: 0.484037, Recon D: 0.023464, Recon V: 0.059092, CR X: 0.155827, CR Z: 0.042304, Cons Z: 0.039241, Cons X: 0.045002, Roll D: 0.023059, Roll V: 0.058927, Roll ZD: 0.000004, Roll ZV: 0.000245, LD: 0.032674, Coef: 616.526917, max|c|: 85.4,
# 16:28:01.569 - GPLaSDI:train:715 - INFO - Iter: 00045/4000, Total: 0.484037, Recon D: 0.023464, Recon V: 0.059092, CR X: 0.155827, CR Z: 0.042304, Cons Z: 0.039241, Cons X: 0.045002, Roll D: 0.023059, Roll V: 0.058927, Roll ZD: 0.000004, Roll ZV: 0.000245, LD: 0.032674, Coef: 616.526917, max|c|: 85.4,
# 16:28:01.661 - GPLaSDI:train:715 - INFO - Iter: 00046/4000, Total: 0.442756, Recon D: 0.020686, Recon V: 0.054831, CR X: 0.132039, CR Z: 0.044915, Cons Z: 0.040778, Cons X: 0.036411, Roll D: 0.020352, Roll V: 0.054642, Roll ZD: 0.000004, Roll ZV: 0.000236, LD: 0.032742, Coef: 591.084351, max|c|: 82.1,
# 16:28:01.661 - GPLaSDI:train:715 - INFO - Iter: 00046/4000, Total: 0.442756, Recon D: 0.020686, Recon V: 0.054831, CR X: 0.132039, CR Z: 0.044915, Cons Z: 0.040778, Cons X: 0.036411, Roll D: 0.020352, Roll V: 0.054642, Roll ZD: 0.000004, Roll ZV: 0.000236, LD: 0.032742, Coef: 591.084351, max|c|: 82.1,
# 16:28:01.761 - GPLaSDI:train:715 - INFO - Iter: 00047/4000, Total: 0.402048, Recon D: 0.018161, Recon V: 0.051631, CR X: 0.110955, CR Z: 0.044672, Cons Z: 0.040298, Cons X: 0.028952, Roll D: 0.017890, Roll V: 0.051430, Roll ZD: 0.000004, Roll ZV: 0.000228, LD: 0.033141, Coef: 560.317017, max|c|: 80.0,
# 16:28:01.761 - GPLaSDI:train:715 - INFO - Iter: 00047/4000, Total: 0.402048, Recon D: 0.018161, Recon V: 0.051631, CR X: 0.110955, CR Z: 0.044672, Cons Z: 0.040298, Cons X: 0.028952, Roll D: 0.017890, Roll V: 0.051430, Roll ZD: 0.000004, Roll ZV: 0.000228, LD: 0.033141, Coef: 560.317017, max|c|: 80.0,
# ...
# 16:34:36.897 - GPLaSDI:train:715 - INFO - Iter: 02730/4000, Total: 0.077887, Recon D: 0.005275, Recon V: 0.011427, CR X: 0.025893, CR Z: 0.003461, Cons Z: 0.004268, Cons X: 0.003241, Roll D: 0.004378, Roll V: 0.010462, Roll ZD: 0.000021, Roll ZV: 0.001159, LD: 0.009093, Coef: 117.644035, max|c|: 10.0,
# 16:34:36.897 - GPLaSDI:train:715 - INFO - Iter: 02730/4000, Total: 0.077887, Recon D: 0.005275, Recon V: 0.011427, CR X: 0.025893, CR Z: 0.003461, Cons Z: 0.004268, Cons X: 0.003241, Roll D: 0.004378, Roll V: 0.010462, Roll ZD: 0.000021, Roll ZV: 0.001159, LD: 0.009093, Coef: 117.644035, max|c|: 10.0,
# 16:34:37.100 - GPLaSDI:train:715 - INFO - Iter: 02731/4000, Total: 0.080287, Recon D: 0.005384, Recon V: 0.011438, CR X: 0.026776, CR Z: 0.004145, Cons Z: 0.004526, Cons X: 0.003493, Roll D: 0.005457, Roll V: 0.010559, Roll ZD: 0.000023, Roll ZV: 0.001109, LD: 0.009339, Coef: 112.800629, max|c|: 09.7,
# 16:34:37.100 - GPLaSDI:train:715 - INFO - Iter: 02731/4000, Total: 0.080287, Recon D: 0.005384, Recon V: 0.011438, CR X: 0.026776, CR Z: 0.004145, Cons Z: 0.004526, Cons X: 0.003493, Roll D: 0.005457, Roll V: 0.010559, Roll ZD: 0.000023, Roll ZV: 0.001109, LD: 0.009339, Coef: 112.800629, max|c|: 09.7,
# 16:34:37.297 - GPLaSDI:train:715 - INFO - Iter: 02732/4000, Total: 0.078456, Recon D: 0.005820, Recon V: 0.011565, CR X: 0.023821, CR Z: 0.003942, Cons Z: 0.004367, Cons X: 0.003954, Roll D: 0.004548, Roll V: 0.010544, Roll ZD: 0.000022, Roll ZV: 0.001181, LD: 0.009391, Coef: 121.440208, max|c|: 10.4,
# 16:34:37.297 - GPLaSDI:train:715 - INFO - Iter: 02732/4000, Total: 0.078456, Recon D: 0.005820, Recon V: 0.011565, CR X: 0.023821, CR Z: 0.003942, Cons Z: 0.004367, Cons X: 0.003954, Roll D: 0.004548, Roll V: 0.010544, Roll ZD: 0.000022, Roll ZV: 0.001181, LD: 0.009391, Coef: 121.440208, max|c|: 10.4,
# 16:34:37.510 - GPLaSDI:train:715 - INFO - Iter: 02733/4000, Total: 0.088483, Recon D: 0.004944, Recon V: 0.011792, CR X: 0.032591, CR Z: 0.003167, Cons Z: 0.004884, Cons X: 0.005338, Roll D: 0.004738, Roll V: 0.011195, Roll ZD: 0.000025, Roll ZV: 0.001092, LD: 0.009645, Coef: 124.206810, max|c|: 10.6,
# 16:34:37.510 - GPLaSDI:train:715 - INFO - Iter: 02733/4000, Total: 0.088483, Recon D: 0.004944, Recon V: 0.011792, CR X: 0.032591, CR Z: 0.003167, Cons Z: 0.004884, Cons X: 0.005338, Roll D: 0.004738, Roll V: 0.011195, Roll ZD: 0.000025, Roll ZV: 0.001092, LD: 0.009645, Coef: 124.206810, max|c|: 10.6,
# 16:34:37.705 - GPLaSDI:train:715 - INFO - Iter: 02734/4000, Total: 0.077305, Recon D: 0.005305, Recon V: 0.012162, CR X: 0.022051, CR Z: 0.003965, Cons Z: 0.004121, Cons X: 0.004704, Roll D: 0.004474, Roll V: 0.011056, Roll ZD: 0.000020, Roll ZV: 0.001167, LD: 0.009234, Coef: 120.229210, max|c|: 10.2,
# 16:34:37.705 - GPLaSDI:train:715 - INFO - Iter: 02734/4000, Total: 0.077305, Recon D: 0.005305, Recon V: 0.012162, CR X: 0.022051, CR Z: 0.003965, Cons Z: 0.004121, Cons X: 0.004704, Roll D: 0.004474, Roll V: 0.011056, Roll ZD: 0.000020, Roll ZV: 0.001167, LD: 0.009234, Coef: 120.229210, max|c|: 10.2,
# 16:34:37.890 - GPLaSDI:train:715 - INFO - Iter: 02735/4000, Total: 0.078989, Recon D: 0.005014, Recon V: 0.011292, CR X: 0.028583, CR Z: 0.003631, Cons Z: 0.004342, Cons X: 0.003962, Roll D: 0.004664, Roll V: 0.010583, Roll ZD: 0.000021, Roll ZV: 0.001112, LD: 0.009303, Coef: 93.230415, max|c|: 06.9,
# 16:34:37.890 - GPLaSDI:train:715 - INFO - Iter: 02735/4000, Total: 0.078989, Recon D: 0.005014, Recon V: 0.011292, CR X: 0.028583, CR Z: 0.003631, Cons Z: 0.004342, Cons X: 0.003962, Roll D: 0.004664, Roll V: 0.010583, Roll ZD: 0.000021, Roll ZV: 0.001112, LD: 0.009303, Coef: 93.230415, max|c|: 06.9,
# 16:34:38.070 - GPLaSDI:train:715 - INFO - Iter: 02736/4000, Total: 0.075440, Recon D: 0.005483, Recon V: 0.011280, CR X: 0.025714, CR Z: 0.003837, Cons Z: 0.004124, Cons X: 0.003200, Roll D: 0.004412, Roll V: 0.010480, Roll ZD: 0.000020, Roll ZV: 0.001172, LD: 0.009515, Coef: 90.037384, max|c|: 07.5,
# 16:34:38.070 - GPLaSDI:train:715 - INFO - Iter: 02736/4000, Total: 0.075440, Recon D: 0.005483, Recon V: 0.011280, CR X: 0.025714, CR Z: 0.003837, Cons Z: 0.004124, Cons X: 0.003200, Roll D: 0.004412, Roll V: 0.010480, Roll ZD: 0.000020, Roll ZV: 0.001172, LD: 0.009515, Coef: 90.037384, max|c|: 07.5,
# 16:34:38.266 - GPLaSDI:train:715 - INFO - Iter: 02737/4000, Total: 0.077513, Recon D: 0.005193, Recon V: 0.011323, CR X: 0.024662, CR Z: 0.004149, Cons Z: 0.004350, Cons X: 0.003380, Roll D: 0.004879, Roll V: 0.010502, Roll ZD: 0.000022, Roll ZV: 0.001156, LD: 0.009384, Coef: 114.853279, max|c|: 14.7,
# 16:34:38.266 - GPLaSDI:train:715 - INFO - Iter: 02737/4000, Total: 0.077513, Recon D: 0.005193, Recon V: 0.011323, CR X: 0.024662, CR Z: 0.004149, Cons Z: 0.004350, Cons X: 0.003380, Roll D: 0.004879, Roll V: 0.010502, Roll ZD: 0.000022, Roll ZV: 0.001156, LD: 0.009384, Coef: 114.853279, max|c|: 14.7,
# 16:34:38.462 - GPLaSDI:train:715 - INFO - Iter: 02738/4000, Total: 0.080589, Recon D: 0.005035, Recon V: 0.011167, CR X: 0.027241, CR Z: 0.003562, Cons Z: 0.004508, Cons X: 0.003867, Roll D: 0.004458, Roll V: 0.010480, Roll ZD: 0.000022, Roll ZV: 0.001103, LD: 0.009201, Coef: 125.755753, max|c|: 13.2,
# 16:34:38.462 - GPLaSDI:train:715 - INFO - Iter: 02738/4000, Total: 0.080589, Recon D: 0.005035, Recon V: 0.011167, CR X: 0.027241, CR Z: 0.003562, Cons Z: 0.004508, Cons X: 0.003867, Roll D: 0.004458, Roll V: 0.010480, Roll ZD: 0.000022, Roll ZV: 0.001103, LD: 0.009201, Coef: 125.755753, max|c|: 13.2,
# 16:34:38.658 - GPLaSDI:train:715 - INFO - Iter: 02739/4000, Total: 0.076943, Recon D: 0.005550, Recon V: 0.011429, CR X: 0.023629, CR Z: 0.003911, Cons Z: 0.003986, Cons X: 0.003366, Roll D: 0.004464, Roll V: 0.010502, Roll ZD: 0.000018, Roll ZV: 0.001192, LD: 0.008842, Coef: 125.620262, max|c|: 12.8,
# 16:34:38.658 - GPLaSDI:train:715 - INFO - Iter: 02739/4000, Total: 0.076943, Recon D: 0.005550, Recon V: 0.011429, CR X: 0.023629, CR Z: 0.003911, Cons Z: 0.003986, Cons X: 0.003366, Roll D: 0.004464, Roll V: 0.010502, Roll ZD: 0.000018, Roll ZV: 0.001192, LD: 0.008842, Coef: 125.620262, max|c|: 12.8,
# 16:34:38.855 - GPLaSDI:train:715 - INFO - Iter: 02740/4000, Total: 0.077315, Recon D: 0.005404, Recon V: 0.011229, CR X: 0.026258, CR Z: 0.003430, Cons Z: 0.004279, Cons X: 0.003744, Roll D: 0.005601, Roll V: 0.010432, Roll ZD: 0.000021, Roll ZV: 0.001157, LD: 0.009438, Coef: 96.454369, max|c|: 07.7,
# 16:34:38.855 - GPLaSDI:train:715 - INFO - Iter: 02740/4000, Total: 0.077315, Recon D: 0.005404, Recon V: 0.011229, CR X: 0.026258, CR Z: 0.003430, Cons Z: 0.004279, Cons X: 0.003744, Roll D: 0.005601, Roll V: 0.010432, Roll ZD: 0.000021, Roll ZV: 0.001157, LD: 0.009438, Coef: 96.454369, max|c|: 07.7,
# 16:34:39.074 - GPLaSDI:train:715 - INFO - Iter: 02741/4000, Total: 0.074479, Recon D: 0.005827, Recon V: 0.011256, CR X: 0.024948, CR Z: 0.003491, Cons Z: 0.004074, Cons X: 0.003330, Roll D: 0.004561, Roll V: 0.010377, Roll ZD: 0.000019, Roll ZV: 0.001180, LD: 0.009309, Coef: 88.296852, max|c|: 09.5,
# 16:34:39.074 - GPLaSDI:train:715 - INFO - Iter: 02741/4000, Total: 0.074479, Recon D: 0.005827, Recon V: 0.011256, CR X: 0.024948, CR Z: 0.003491, Cons Z: 0.004074, Cons X: 0.003330, Roll D: 0.004561, Roll V: 0.010377, Roll ZD: 0.000019, Roll ZV: 0.001180, LD: 0.009309, Coef: 88.296852, max|c|: 09.5,
# 16:34:39.276 - GPLaSDI:train:715 - INFO - Iter: 02742/4000, Total: 0.079431, Recon D: 0.005136, Recon V: 0.011302, CR X: 0.027547, CR Z: 0.003549, Cons Z: 0.004236, Cons X: 0.003481, Roll D: 0.004791, Roll V: 0.010563, Roll ZD: 0.000020, Roll ZV: 0.001154, LD: 0.009155, Coef: 113.393906, max|c|: 09.5,
# 16:34:39.276 - GPLaSDI:train:715 - INFO - Iter: 02742/4000, Total: 0.079431, Recon D: 0.005136, Recon V: 0.011302, CR X: 0.027547, CR Z: 0.003549, Cons Z: 0.004236, Cons X: 0.003481, Roll D: 0.004791, Roll V: 0.010563, Roll ZD: 0.000020, Roll ZV: 0.001154, LD: 0.009155, Coef: 113.393906, max|c|: 09.5,
# 16:34:39.475 - GPLaSDI:train:715 - INFO - Iter: 02743/4000, Total: 0.078676, Recon D: 0.005194, Recon V: 0.011281, CR X: 0.025365, CR Z: 0.003607, Cons Z: 0.004463, Cons X: 0.003445, Roll D: 0.004564, Roll V: 0.010412, Roll ZD: 0.000022, Roll ZV: 0.001155, LD: 0.009392, Coef: 125.486282, max|c|: 12.3,
# 16:34:39.475 - GPLaSDI:train:715 - INFO - Iter: 02743/4000, Total: 0.078676, Recon D: 0.005194, Recon V: 0.011281, CR X: 0.025365, CR Z: 0.003607, Cons Z: 0.004463, Cons X: 0.003445, Roll D: 0.004564, Roll V: 0.010412, Roll ZD: 0.000022, Roll ZV: 0.001155, LD: 0.009392, Coef: 125.486282, max|c|: 12.3,
# 16:34:39.680 - GPLaSDI:train:715 - INFO - Iter: 02744/4000, Total: 0.084066, Recon D: 0.005264, Recon V: 0.011361, CR X: 0.028266, CR Z: 0.004167, Cons Z: 0.005121, Cons X: 0.003773, Roll D: 0.004446, Roll V: 0.010616, Roll ZD: 0.000028, Roll ZV: 0.001201, LD: 0.009690, Coef: 131.236145, max|c|: 13.8,
# 16:34:39.680 - GPLaSDI:train:715 - INFO - Iter: 02744/4000, Total: 0.084066, Recon D: 0.005264, Recon V: 0.011361, CR X: 0.028266, CR Z: 0.004167, Cons Z: 0.005121, Cons X: 0.003773, Roll D: 0.004446, Roll V: 0.010616, Roll ZD: 0.000028, Roll ZV: 0.001201, LD: 0.009690, Coef: 131.236145, max|c|: 13.8,
# 16:34:39.918 - GPLaSDI:train:715 - INFO - Iter: 02745/4000, Total: 0.076052, Recon D: 0.005177, Recon V: 0.011566, CR X: 0.023611, CR Z: 0.004591, Cons Z: 0.005114, Cons X: 0.003771, Roll D: 0.004704, Roll V: 0.010422, Roll ZD: 0.000029, Roll ZV: 0.001171, LD: 0.009123, Coef: 94.972687, max|c|: 08.1,
# 16:34:39.918 - GPLaSDI:train:715 - INFO - Iter: 02745/4000, Total: 0.076052, Recon D: 0.005177, Recon V: 0.011566, CR X: 0.023611, CR Z: 0.004591, Cons Z: 0.005114, Cons X: 0.003771, Roll D: 0.004704, Roll V: 0.010422, Roll ZD: 0.000029, Roll ZV: 0.001171, LD: 0.009123, Coef: 94.972687, max|c|: 08.1,
# 16:34:40.131 - GPLaSDI:train:715 - INFO - Iter: 02746/4000, Total: 0.082694, Recon D: 0.005074, Recon V: 0.011460, CR X: 0.029321, CR Z: 0.004009, Cons Z: 0.004535, Cons X: 0.003997, Roll D: 0.004507, Roll V: 0.010762, Roll ZD: 0.000023, Roll ZV: 0.001143, LD: 0.009281, Coef: 114.404083, max|c|: 08.4,
# 16:34:40.131 - GPLaSDI:train:715 - INFO - Iter: 02746/4000, Total: 0.082694, Recon D: 0.005074, Recon V: 0.011460, CR X: 0.029321, CR Z: 0.004009, Cons Z: 0.004535, Cons X: 0.003997, Roll D: 0.004507, Roll V: 0.010762, Roll ZD: 0.000023, Roll ZV: 0.001143, LD: 0.009281, Coef: 114.404083, max|c|: 08.4,
# 16:34:40.340 - GPLaSDI:train:715 - INFO - Iter: 02747/4000, Total: 0.078421, Recon D: 0.005733, Recon V: 0.011750, CR X: 0.023650, CR Z: 0.004123, Cons Z: 0.004116, Cons X: 0.004726, Roll D: 0.004534, Roll V: 0.010749, Roll ZD: 0.000020, Roll ZV: 0.001208, LD: 0.009182, Coef: 114.764954, max|c|: 08.7,
# 16:34:40.340 - GPLaSDI:train:715 - INFO - Iter: 02747/4000, Total: 0.078421, Recon D: 0.005733, Recon V: 0.011750, CR X: 0.023650, CR Z: 0.004123, Cons Z: 0.004116, Cons X: 0.004726, Roll D: 0.004534, Roll V: 0.010749, Roll ZD: 0.000020, Roll ZV: 0.001208, LD: 0.009182, Coef: 114.764954, max|c|: 08.7,
# 16:34:40.532 - GPLaSDI:train:715 - INFO - Iter: 02748/4000, Total: 0.095557, Recon D: 0.005561, Recon V: 0.011532, CR X: 0.034922, CR Z: 0.003651, Cons Z: 0.005307, Cons X: 0.006279, Roll D: 0.006361, Roll V: 0.011011, Roll ZD: 0.000029, Roll ZV: 0.001121, LD: 0.009238, Coef: 144.251495, max|c|: 13.5,
# 16:34:40.532 - GPLaSDI:train:715 - INFO - Iter: 02748/4000, Total: 0.095557, Recon D: 0.005561, Recon V: 0.011532, CR X: 0.034922, CR Z: 0.003651, Cons Z: 0.005307, Cons X: 0.006279, Roll D: 0.006361, Roll V: 0.011011, Roll ZD: 0.000029, Roll ZV: 0.001121, LD: 0.009238, Coef: 144.251495, max|c|: 13.5,
# 16:34:40.730 - GPLaSDI:train:715 - INFO - Iter: 02749/4000, Total: 0.081511, Recon D: 0.007876, Recon V: 0.012263, CR X: 0.021751, CR Z: 0.004485, Cons Z: 0.004035, Cons X: 0.006598, Roll D: 0.006203, Roll V: 0.011127, Roll ZD: 0.000019, Roll ZV: 0.001181, LD: 0.009334, Coef: 105.706421, max|c|: 09.8,
# 16:34:40.730 - GPLaSDI:train:715 - INFO - Iter: 02749/4000, Total: 0.081511, Recon D: 0.007876, Recon V: 0.012263, CR X: 0.021751, CR Z: 0.004485, Cons Z: 0.004035, Cons X: 0.006598, Roll D: 0.006203, Roll V: 0.011127, Roll ZD: 0.000019, Roll ZV: 0.001181, LD: 0.009334, Coef: 105.706421, max|c|: 09.8,
# 16:34:40.951 - GPLaSDI:train:715 - INFO - Iter: 02750/4000, Total: 0.101415, Recon D: 0.007056, Recon V: 0.011833, CR X: 0.036035, CR Z: 0.004078, Cons Z: 0.005731, Cons X: 0.010606, Roll D: 0.009239, Roll V: 0.011320, Roll ZD: 0.000032, Roll ZV: 0.001115, LD: 0.009178, Coef: 106.354706, max|c|: 09.5,
# 16:34:40.951 - GPLaSDI:train:715 - INFO - Iter: 02750/4000, Total: 0.101415, Recon D: 0.007056, Recon V: 0.011833, CR X: 0.036035, CR Z: 0.004078, Cons Z: 0.005731, Cons X: 0.010606, Roll D: 0.009239, Roll V: 0.011320, Roll ZD: 0.000032, Roll ZV: 0.001115, LD: 0.009178, Coef: 106.354706, max|c|: 09.5,
# 16:34:41.200 - GPLaSDI:train:715 - INFO - Iter: 02751/4000, Total: 0.103232, Recon D: 0.010825, Recon V: 0.014844, CR X: 0.021781, CR Z: 0.007467, Cons Z: 0.006257, Cons X: 0.015489, Roll D: 0.009187, Roll V: 0.013239, Roll ZD: 0.000039, Roll ZV: 0.001150, LD: 0.009064, Coef: 102.289474, max|c|: 08.9,
# 16:34:41.200 - GPLaSDI:train:715 - INFO - Iter: 02751/4000, Total: 0.103232, Recon D: 0.010825, Recon V: 0.014844, CR X: 0.021781, CR Z: 0.007467, Cons Z: 0.006257, Cons X: 0.015489, Roll D: 0.009187, Roll V: 0.013239, Roll ZD: 0.000039, Roll ZV: 0.001150, LD: 0.009064, Coef: 102.289474, max|c|: 08.9,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 89
#      86     Run_Samples(trainer, config);
#      88 # train over given training data
# ---> 89 trainer.train();
#      91 # Plot
#      92 Plot_Reconstruction(
#      93     X_True  = trainer.X_Test[index_plot],
#      94     model   = trainer.model,
#      95     t_grid  = trainer.t_Test[index_plot].numpy(),
#      96     x_grid  = trainer.physics.X_Positions);
#
# File ~/Documents/Projects/Second Order LaSDI/src/GPLaSDI.py:689, in BayesianGLaSDI.train(self)
#     686 self.timer.start("Backwards Pass");
#     688 #  Run back propagation and update the model parameters.
# --> 689 loss.backward();
#     690 self.optimizer.step();
#     692 # Check if we hit a new minimum loss. If so, make a checkpoint, record the loss and
#     693 # the iteration number.
#
# File ~/miniconda3/envs/LaSDI/lib/python3.10/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/miniconda3/envs/LaSDI/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/LaSDI/lib/python3.10/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Loading From a Save
#
#
# If you instead want to load a saved model, we can load the restart file for post-training.

# %%
# Add src directory to the search path
import  os;
import  sys;
src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
sys.path.append(src_path);

import  yaml;
import  logging;

import  numpy; 
import  torch;

from    ParameterSpace  import  ParameterSpace;
from    Initialize      import  Initialize_Trainer;



# Specify the restart file you have.
filename    : str   = 'lasdi_04_30_2025_17_32.npy'
cfg_file    : str   = 'Explicit.yml'
with open(cfg_file, 'r') as f:
    config = yaml.safe_load(f)

file_path   : str   = os.path.join(os.path.join(os.path.pardir, "results"), filename);
restart_file        = numpy.load(file_path, allow_pickle = True).item()

trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config, restart_file)

# %% [markdown]
# # Post-processing

# %% [markdown]
# Setup data for post-processing:

# %%
n_coef          : int                       = latent_dynamics.n_coefs;
n_IC            : int                       = latent_dynamics.n_IC; 
n_p             : int                       = param_space.n_p; 

coefs           : numpy.ndarray             = trainer.best_coefs;           # shape = (n_train, n_coefs).
X_Train         : list[list[torch.Tensor]]  = trainer.X_Train;              # len = n_train. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM train solve
X_Test          : list[list[torch.Tensor]]  = trainer.X_Test;               # len = n_test. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM test solve.
t_Train         : list[torch.Tensor]        = trainer.t_Train;              # len = n_train. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM train solve.
t_Test          : list[torch.Tensor]        = trainer.t_Test;               # len = n_test. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM test solve.
n_samples       : int                       = trainer.n_samples;

param_train     : numpy.ndarray             = param_space.train_space;      # shape = (n_train, n_p)
param_test      : numpy.ndarray             = param_space.test_space;       # shape = (n_test, n_p)
param_names     : list[str]                 = param_space.param_names;

test_meshgrid   : tuple[numpy.ndarray]      = param_space.test_meshgrid;    # len = n_p. i'th element is meshgrid for i'th parameter.
test_grid_sizes : list[int]                 = param_space.test_grid_sizes;  # len = n_p. i'th element holds the number of values of the i'th parameter in the test set.
n_init_train    : int                       = param_space.n_init_train;     # The initial number of combinations of parameters in the training set.
n_train         : int                       = param_space.n_train();
n_test          : int                       = param_space.n_test();

X_Positions     : numpy.ndarray             = physics.X_Positions;          # Spatial discretization of FOM problem domain.
assert(X_Positions.ndim == 1);

# %% [markdown]
# ## Gaussian-process uncertainty evaluation
# For each combination of parameters, evaluate the coefficient GPs to generate a set of coefficients for the latent dynamics for that parameter combination. Then solve each latent dynamics forward in time.

# %%
# First, we need to import a few new things.
import os;
import sys;
physics_path    : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Physics");
utils_path      : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Utilities");
sys.path.append(physics_path);

from    sklearn.gaussian_process    import  GaussianProcessRegressor;

import  SolveROMs;
import  GaussianProcess;
from    Physics                     import  Physics;
from    Model                       import  Autoencoder, Autoencoder_Pair;

# Setup
model.cpu();



# Get a GP for each coefficient in the latent dynamics.
gp_list         : list[GaussianProcessRegressor]    = GaussianProcess.fit_gps(param_space.train_space, coefs);

Zis_samples     : list[list[numpy.ndarray]] = SolveROMs.sample_roms(model, physics, latent_dynamics, gp_list, param_test, t_Test, n_samples);    # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_samples, n_z)
Zis_mean        : list[list[numpy.ndarray]] = SolveROMs.average_rom(model, physics, latent_dynamics, gp_list, param_test, t_Test);               # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_z)

# %% [markdown]
# Now, decode the latent trajectories and compare them to the test set. Use these values to compute some errors.

# %%
# Set up arrays to hold the average error between X_pred_mean and X_test, as well as the std of 
# the predictions.
mean_rel_error   : list[numpy.ndarray]   = [];
max_std          : list[numpy.ndarray]   = [];
for d in range(n_IC):
    mean_rel_error.append(  numpy.zeros(n_test, dtype = numpy.float32));
    max_std.append(         numpy.zeros(n_test, dtype = numpy.float32));



# Pass the samples through the decoder. The way this works depends on what kind of model we are using. 
if(isinstance(model, Autoencoder)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        X_pred_mean.append([model.Decode(torch.Tensor(Zis_mean[i][0])).detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_X_Pred   : numpy.ndarray            = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            X_Pred_ij                           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]));
            ith_X_Pred[:, j, :]                 = X_Pred_ij.detach().numpy();

        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_X_Pred.std(axis = 1).max();
    
    

elif(isinstance(model, Autoencoder_Pair)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        Disp_Pred_mean_i, Vel_Pred_mean_i   = model.Decode(torch.Tensor(Zis_mean[i][0]), torch.Tensor(Zis_mean[i][1]));
        X_pred_mean.append([Disp_Pred_mean_i.detach().numpy(), Vel_Pred_mean_i.detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_Disp_Pred   : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);
        ith_Vel_Pred    : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            Disp_Pred_ij, Vel_Pred_ij           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]), torch.Tensor(Zis_samples[i][1][:, j, :]));
            ith_Disp_Pred[:, j, :]              = Disp_Pred_ij.detach().numpy();
            ith_Vel_Pred[:, j, :]               = Vel_Pred_ij.detach().numpy();


        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_Disp_Pred.std(axis = 1).max();
        max_std[1][i]                           = ith_Vel_Pred.std(axis = 1).max();



# For each d \in {0, 1, ... , n_{IC} - 1} and k \in {1, 2, ... , n_test - 1}, find the mean 
# error between X_Pred_mean[d][k, ...] and X_test[d][k, ...].
for d in range(n_IC):
    for k in range(n_test):        
        # Extract the prediction, true values for the d'th component of the FOM solution when we use 
        # the k'th parameter value. These have shape (n_t, n_x).
        kth_X_Pred_d            : numpy.ndarray = X_pred_mean[k][d];
        kth_X_Test_d            : numpy.ndarray = X_Test[k][d].numpy();
        
        # For each compute the relative error between the predicted and true values of the d'th 
        # derivative of the FOM solution at each time step when we use the k'th combination of 
        # parameter values.
        kth_Relative_Errors_d   : numpy.ndarray = numpy.linalg.norm(kth_X_Pred_d - kth_X_Test_d, axis = 1) / numpy.linalg.norm(kth_X_Test_d, axis = 1);
        mean_rel_error[d][k]                    = kth_Relative_Errors_d.max();



# Get the mean and std of each coefficient's distribution when we evaluate the posterior coefficient 
# distributions at each testing parameter value. We then reshape these arrays to have shape 
# (N(1), ... , N(n_p)), where N(k) is the number of distinct values of the k'th parameter in the 
# training set. The i(1), ... , i(n_p), j element of the d'th element of these lists will hold the 
# mean and std of the distribution of the j'th parameter when we use the i(k)'th value of the k'th 
# parameter.
gp_pred_mean, gp_pred_std = GaussianProcess.eval_gp(gp_list, param_test);
gp_pred_mean    = gp_pred_mean.reshape(test_grid_sizes + [-1]);
gp_pred_std     = gp_pred_std.reshape(test_grid_sizes + [-1]);

# Reshape each element of mean_rel_error and max_std has shape (N(1), ... , N(n_p)), where N(k) 
# is the number of distinct values of the k'th parameter in the training set. The i(1), ... , i(n_p) 
# element of the d'th element of these lists will hold the mean error and std of the prediction of 
# the d'th derivative of the FOM solution when we use the i(k)'th value of the k'th parameter, 
# respectively.
for d in range(n_IC):
    mean_rel_error[d]   = mean_rel_error[d].reshape(test_grid_sizes);
    max_std[d]          = max_std[d].reshape(test_grid_sizes);

# %% [markdown]
# # Visualization

# %% [markdown]
# Plot mean and standard deviation of coefficient matrix.
# For SINDy of dimension 5, the coefficient matrix has a shape of (6, 5).

# %%
import  Plot;

if(n_p == 2):
    Plot.Plot_GP2d( p1_mesh     = test_meshgrid[0], 
                    p2_mesh     = test_meshgrid[1], 
                    gp_mean     = gp_pred_mean, 
                    gp_std      = gp_pred_std, 
                    param_train = param_train, 
                    param_names = param_names, 
                    n_cols      = 5);

# %%
for d in range(n_IC):
    if(d == 0):
        title_string : str = r'$max_{t} mean_{i} \|x \to \left(\tilde{u}_{\xi^*}^{i}(t, x) - u(t, x) \right) \|/\| x \to u(t, x)\|$';
    else:
        title_string : str = r'$max_{t} mean_{i} \left\|x \to \left( \frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*}^{i}(t, x) - \frac{d^{%d}}{dt^{%d}}u(t, x) \right) \right\|$' % (d, d, d, d);


    Plot.Plot_Heatmap2d(values          = mean_rel_error[d] * 100, 
                        p1_grid         = test_meshgrid[0][:, 0], 
                        p2_grid         = test_meshgrid[1][0, :], 
                        param_train     = param_train, 
                        n_init_train    = param_space.n_init_train, 
                        param_names     = param_names, 
                        title           = title_string);

# %%
import Plot; 

for d in range(n_IC):
    if(d == 0):
        title : str = r'$max_{(t, x)} \sqrt{ V \left[ \tilde{u}_{\xi^*} \right] }$';
    else:
        title : str = r'$max_{(t, x)} \sqrt{ V \left[\frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*} \right] }$' % (d, d);


    Plot.Plot_Heatmap2d(values          = max_std[d] * 100, 
                        p1_grid         = test_meshgrid[0][:, 0], 
                        p2_grid         = test_meshgrid[1][0, :], 
                        param_train     = param_train, 
                        n_init_train    = param_space.n_init_train, 
                        param_names     = param_names, 
                        title           = title);

# %%
import importlib
importlib.reload(Plot);

# Pick some parameter values.
a           : float                 = 0.9;
w           : float                 = 1.07; 
param_grid  : numpy.ndarray         = numpy.array([[a, w]]);

# Get the predicted solution using this parameter value.
X_True, t_Grid = physics.solve(param_grid[0]);


# Plot the predictions!
Plot.Plot_Prediction(
            model           = model, 
            physics         = physics, 
            latent_dynamics = latent_dynamics, 
            param_grid      = param_grid,
            gp_list         = gp_list, 
            n_samples       = n_samples, 
            X_True          = [X_True], 
            t_Grid          = [t_Grid]);
