# %% [markdown]
# # About this Notebook
#
# This notebook should work whenever the FOM depends on two variables (t, x) and whenever the initial condition parameter vector, $\theta$, has two elements (there are two parameters). If your example does not fall into that category, use another notebook!
#
# # Training
#
# First, let us train a higher-order LaSDI model on the Burgers' equation data.
# If you want to load a pre-trained model from a save, go to the next cell.

# %%
# -------------------------------------------------------------------------------------------------
# Imports 
# -------------------------------------------------------------------------------------------------

import  os;
import  sys;

src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
utils_path  : str = os.path.join(src_path, "Utilities");
sys.path.append(src_path);
sys.path.append(utils_path);

import  random;
import  yaml;
import  logging;

import  torch
import  numpy;

from    Workflow    import  Save;
from    Enums       import  NextStep, Result
from    Sample      import  Run_Samples, Update_Train_Space;
from    Initialize  import  Initialize_Trainer;
from    Logging     import  Initialize_Logger, Log_Dictionary;
from    Plot        import  Plot_Reconstruction;



# -------------------------------------------------------------------------------------------------
# Setup
# -------------------------------------------------------------------------------------------------

# Set up the logger
Initialize_Logger(logging.INFO);
LOGGER  : logging.Logger    = logging.getLogger(__name__);

# Load the configuration.
cfg_file : str = 'burgers.yml';
#cfg_file : str = 'explicit.yml';
with open(cfg_file, 'r') as f:
    config : dict = yaml.safe_load(f);
Log_Dictionary(LOGGER = LOGGER, D = config, level = logging.DEBUG);

# Setup the trainer
trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config);



# -------------------------------------------------------------------------------------------------
# Train
# -------------------------------------------------------------------------------------------------

LOGGER.info("Training with %d epochs" % trainer.max_iter);

# generate initial training/test data
Update_Train_Space(trainer, config);
Run_Samples(trainer, config);



# Fetch the number of testing, training examples.
n_train : int   = param_space.n_train();
n_test  : int   = param_space.n_test();
n_IC    : int   = latent_dynamics.n_IC;

# initial training given training data
trainer.train();


# Select a random parameter combination to investigate.
index_plot  : int = random.randrange(0, n_test);
print("Plotting testing parameter combination number %d (%s = %s)" % (index_plot, str(param_space.param_names), str(param_space.test_space[index_plot, :])));

Plot_Reconstruction(
    X_True  = trainer.X_Test[index_plot],
    model   = trainer.model, 
    t_grid  = trainer.t_Test[index_plot].numpy(), 
    x_grid  = trainer.physics.X_Positions);


while (trainer.restart_iter < trainer.max_iter):
    if (trainer.restart_iter <= trainer.max_greedy_iter):
        # perform greedy sampling to pick up new samples
        Update_Train_Space(trainer, config);
        # update training data with newly picked samples
        Run_Samples(trainer, config);

    # train over given training data
    trainer.train();

    # Plot 
    Plot_Reconstruction(  
        X_True  = trainer.X_Test[index_plot],
        model   = trainer.model, 
        t_grid  = trainer.t_Test[index_plot].numpy(), 
        x_grid  = trainer.physics.X_Positions);


# Finally, save!
Save(   param_space         = param_space, 
        physics             = physics, 
        model               = model, 
        latent_dynamics     = latent_dynamics, 
        trainer             = trainer, 
        next_step           = NextStep.PickSample, 
        result              = Result.Success,
        restart_filename    = None);
# Out:
# 16:13:29.089 - Initialize:Initialize_Trainer:109 - INFO - Initializing Trainer (gplasdi)
# 16:13:29.089 - Initialize:Initialize_Trainer:109 - INFO - Initializing Trainer (gplasdi)
# 16:13:29.089 - ParameterSpace:__init__:174 - INFO - Initializing a ParameterSpace object with parameters ['a', 'w']
# 16:13:29.089 - ParameterSpace:__init__:174 - INFO - Initializing a ParameterSpace object with parameters ['a', 'w']
# 16:13:29.090 - ParameterSpace:__init__:182 - INFO - The testing set has 25 parameter combinations
# 16:13:29.090 - ParameterSpace:__init__:182 - INFO - The testing set has 25 parameter combinations
# 16:13:29.090 - ParameterSpace:__init__:189 - INFO - The training set has 4 parameter combinations
# 16:13:29.090 - ParameterSpace:__init__:189 - INFO - The training set has 4 parameter combinations
# 16:13:29.091 - Initialize:Initialize_Physics:249 - INFO - Initializing Physics (Burgers)
# 16:13:29.091 - Initialize:Initialize_Physics:249 - INFO - Initializing Physics (Burgers)
# 16:13:29.092 - Initialize:Initialize_Model:191 - INFO - Initializing Model (ae)
# 16:13:29.092 - Initialize:Initialize_Model:191 - INFO - Initializing Model (ae)
# 16:13:29.092 - Model:__init__:286 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:13:29.092 - Model:__init__:286 - INFO - Initializing an Autoencoder with latent space dimension 5
# 16:13:29.093 - Model:__init__:289 - INFO - Initializing the encoder...
# 16:13:29.093 - Model:__init__:289 - INFO - Initializing the encoder...
# 16:13:29.094 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:13:29.094 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [1001, 100, 5], activation tanh, reshape_shape = [1001] (index 0)
# 16:13:29.095 - Model:__init__:296 - INFO - Initializing the decoder...
# 16:13:29.095 - Model:__init__:296 - INFO - Initializing the decoder...
# 16:13:29.096 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:13:29.096 - Model:__init__:140 - INFO - Initializing a MultiLayerPerceptron with widths [5, 100, 1001], activation tanh, reshape_shape = [1001] (index -1)
# 16:13:29.096 - SINDy:__init__:69 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = True
# 16:13:29.096 - SINDy:__init__:69 - INFO - Initializing a SINDY object with n_z = 5, coef_norm_order = fro, Uniform_t_Grid = True
# 16:13:29.097 - GPLaSDI:__init__:148 - INFO - Initializing a GPLaSDI object
# 16:13:29.097 - GPLaSDI:__init__:148 - INFO - Initializing a GPLaSDI object
# 16:13:29.459 - __main__:<module>:53 - INFO - Training with 900 epochs
# 16:13:29.459 - __main__:<module>:53 - INFO - Training with 900 epochs
# 16:13:29.460 - Sample:Run_Samples:116 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 16:13:29.460 - Sample:Run_Samples:116 - INFO - Adding 4 new parameter combinations to the training set (currently has 0)
# 16:13:29.461 - Sample:Run_Samples:135 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 16:13:29.461 - Sample:Run_Samples:135 - INFO - Adding 25 new parameter combinations to the testing set (currently has 0)
# 16:13:29.462 - Physics:generate_solutions:222 - INFO - Generating solution for 4 parameter combinations
# 16:13:29.462 - Physics:generate_solutions:222 - INFO - Generating solution for 4 parameter combinations
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/scipy/sparse/_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# 16:13:29.610 - Physics:generate_solutions:237 - INFO - 1/4 complete
# 16:13:29.610 - Physics:generate_solutions:237 - INFO - 1/4 complete
# 16:13:29.778 - Physics:generate_solutions:237 - INFO - 2/4 complete
# 16:13:29.778 - Physics:generate_solutions:237 - INFO - 2/4 complete
# 16:13:29.943 - Physics:generate_solutions:237 - INFO - 3/4 complete
# 16:13:29.943 - Physics:generate_solutions:237 - INFO - 3/4 complete
# 16:13:30.108 - Physics:generate_solutions:237 - INFO - 4/4 complete
# 16:13:30.108 - Physics:generate_solutions:237 - INFO - 4/4 complete
# 16:13:30.109 - Physics:generate_solutions:222 - INFO - Generating solution for 25 parameter combinations
# 16:13:30.109 - Physics:generate_solutions:222 - INFO - Generating solution for 25 parameter combinations
# 16:13:30.274 - Physics:generate_solutions:237 - INFO - 1/25 complete
# 16:13:30.274 - Physics:generate_solutions:237 - INFO - 1/25 complete
# 16:13:30.436 - Physics:generate_solutions:237 - INFO - 2/25 complete
# 16:13:30.436 - Physics:generate_solutions:237 - INFO - 2/25 complete
# 16:13:30.600 - Physics:generate_solutions:237 - INFO - 3/25 complete
# 16:13:30.600 - Physics:generate_solutions:237 - INFO - 3/25 complete
# 16:13:30.764 - Physics:generate_solutions:237 - INFO - 4/25 complete
# 16:13:30.764 - Physics:generate_solutions:237 - INFO - 4/25 complete
# 16:13:30.929 - Physics:generate_solutions:237 - INFO - 5/25 complete
# 16:13:30.929 - Physics:generate_solutions:237 - INFO - 5/25 complete
# 16:13:31.094 - Physics:generate_solutions:237 - INFO - 6/25 complete
# 16:13:31.094 - Physics:generate_solutions:237 - INFO - 6/25 complete
# 16:13:31.256 - Physics:generate_solutions:237 - INFO - 7/25 complete
# 16:13:31.256 - Physics:generate_solutions:237 - INFO - 7/25 complete
# 16:13:31.420 - Physics:generate_solutions:237 - INFO - 8/25 complete
# 16:13:31.420 - Physics:generate_solutions:237 - INFO - 8/25 complete
# 16:13:31.588 - Physics:generate_solutions:237 - INFO - 9/25 complete
# 16:13:31.588 - Physics:generate_solutions:237 - INFO - 9/25 complete
# 16:13:31.756 - Physics:generate_solutions:237 - INFO - 10/25 complete
# 16:13:31.756 - Physics:generate_solutions:237 - INFO - 10/25 complete
# 16:13:31.919 - Physics:generate_solutions:237 - INFO - 11/25 complete
# 16:13:31.919 - Physics:generate_solutions:237 - INFO - 11/25 complete
# 16:13:32.083 - Physics:generate_solutions:237 - INFO - 12/25 complete
# 16:13:32.083 - Physics:generate_solutions:237 - INFO - 12/25 complete
# 16:13:32.248 - Physics:generate_solutions:237 - INFO - 13/25 complete
# 16:13:32.248 - Physics:generate_solutions:237 - INFO - 13/25 complete
# 16:13:32.410 - Physics:generate_solutions:237 - INFO - 14/25 complete
# 16:13:32.410 - Physics:generate_solutions:237 - INFO - 14/25 complete
# 16:13:32.576 - Physics:generate_solutions:237 - INFO - 15/25 complete
# 16:13:32.576 - Physics:generate_solutions:237 - INFO - 15/25 complete
# 16:13:32.744 - Physics:generate_solutions:237 - INFO - 16/25 complete
# 16:13:32.744 - Physics:generate_solutions:237 - INFO - 16/25 complete
# 16:13:32.913 - Physics:generate_solutions:237 - INFO - 17/25 complete
# 16:13:32.913 - Physics:generate_solutions:237 - INFO - 17/25 complete
# 16:13:33.077 - Physics:generate_solutions:237 - INFO - 18/25 complete
# 16:13:33.077 - Physics:generate_solutions:237 - INFO - 18/25 complete
# 16:13:33.240 - Physics:generate_solutions:237 - INFO - 19/25 complete
# 16:13:33.240 - Physics:generate_solutions:237 - INFO - 19/25 complete
# 16:13:33.393 - Physics:generate_solutions:237 - INFO - 20/25 complete
# 16:13:33.393 - Physics:generate_solutions:237 - INFO - 20/25 complete
# 16:13:33.563 - Physics:generate_solutions:237 - INFO - 21/25 complete
# 16:13:33.563 - Physics:generate_solutions:237 - INFO - 21/25 complete
# 16:13:33.728 - Physics:generate_solutions:237 - INFO - 22/25 complete
# 16:13:33.728 - Physics:generate_solutions:237 - INFO - 22/25 complete
# 16:13:33.884 - Physics:generate_solutions:237 - INFO - 23/25 complete
# 16:13:33.884 - Physics:generate_solutions:237 - INFO - 23/25 complete
# 16:13:34.054 - Physics:generate_solutions:237 - INFO - 24/25 complete
# 16:13:34.054 - Physics:generate_solutions:237 - INFO - 24/25 complete
# 16:13:34.217 - Physics:generate_solutions:237 - INFO - 25/25 complete
# 16:13:34.217 - Physics:generate_solutions:237 - INFO - 25/25 complete
# 16:13:34.218 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 16:13:34.218 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.010000
# 16:13:34.219 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #0 over 5 time steps
# 16:13:34.219 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #0 over 5 time steps
# 16:13:34.223 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #0.
# 16:13:34.223 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #0.
# 16:13:34.223 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 16:13:34.223 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.010000
# 16:13:34.224 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 16:13:34.224 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #1 over 5 time steps
# 16:13:34.228 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #1.
# 16:13:34.228 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #1.
# 16:13:34.228 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 16:13:34.228 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.010000
# 16:13:34.229 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #2 over 5 time steps
# 16:13:34.229 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #2 over 5 time steps
# 16:13:34.233 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #2.
# 16:13:34.233 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #2.
# 16:13:34.234 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 16:13:34.234 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.010000
# 16:13:34.234 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #3 over 5 time steps
# 16:13:34.234 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #3 over 5 time steps
# 16:13:34.238 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 16:13:34.238 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 496 FOM frames for parameter combination #3.
# 16:13:34.301 - GPLaSDI:train:271 - INFO - Training for 300 epochs (starting at 0, going to 300) with 4 parameters
# 16:13:34.301 - GPLaSDI:train:271 - INFO - Training for 300 epochs (starting at 0, going to 300) with 4 parameters
# 16:13:34.362 - GPLaSDI:train:707 - INFO - Iter: 00001/900, Total: 1.2071378231, Recon: 0.7993633747, LD: 0.0000010502, Coef: 80.8734283447, max|c|: 15.8,
# 16:13:34.362 - GPLaSDI:train:707 - INFO - Iter: 00001/900, Total: 1.2071378231, Recon: 0.7993633747, LD: 0.0000010502, Coef: 80.8734283447, max|c|: 15.8,
# 16:13:34.381 - GPLaSDI:train:707 - INFO - Iter: 00002/900, Total: 1.2460806370, Recon: 0.8279126883, LD: 0.0000018545, Coef: 42.4092330933, max|c|: 08.1,
# 16:13:34.381 - GPLaSDI:train:707 - INFO - Iter: 00002/900, Total: 1.2460806370, Recon: 0.8279126883, LD: 0.0000018545, Coef: 42.4092330933, max|c|: 08.1,
# 16:13:34.401 - GPLaSDI:train:707 - INFO - Iter: 00003/900, Total: 1.1570261717, Recon: 0.7682874203, LD: 0.0000009560, Coef: 45.9595565796, max|c|: 08.4,
# 16:13:34.401 - GPLaSDI:train:707 - INFO - Iter: 00003/900, Total: 1.1570261717, Recon: 0.7682874203, LD: 0.0000009560, Coef: 45.9595565796, max|c|: 08.4,
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# 16:13:34.422 - GPLaSDI:train:707 - INFO - Iter: 00004/900, Total: 1.0762764215, Recon: 0.7148246765, LD: 0.0000011809, Coef: 40.1723670959, max|c|: 07.6,
# 16:13:36.634 - GPLaSDI:train:707 - INFO - Iter: 00100/900, Total: 0.0225436985, Recon: 0.0145160360, LD: 0.0000020570, Coef: 8.2965965271, max|c|: 01.1,
# 16:13:36.635 - GPLaSDI:train:282 - INFO - p_rollout is now 0.012000 (increased 0)
# 16:13:36.635 - GPLaSDI:train:282 - INFO - p_rollout is now 0.012000 (increased 0)
# 16:13:36.636 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.012000
# 16:13:36.636 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #0 to t = 0.012000
# 16:13:36.637 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #0 over 7 time steps
# 16:13:36.637 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #0 over 7 time steps
# 16:13:36.641 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 16:13:36.641 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #0.
# 16:13:36.642 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.012000
# 16:13:36.642 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #1 to t = 0.012000
# 16:13:36.642 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #1 over 7 time steps
# 16:13:36.642 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #1 over 7 time steps
# 16:13:36.646 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 16:13:36.646 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #1.
# 16:13:36.647 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.012000
# 16:13:36.647 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #2 to t = 0.012000
# 16:13:36.647 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #2 over 7 time steps
# 16:13:36.647 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #2 over 7 time steps
# 16:13:36.651 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #2.
# 16:13:36.651 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #2.
# 16:13:36.652 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.012000
# 16:13:36.652 - GPLaSDI:_rollout_setup:859 - INFO - We will rollout the first frame for parameter combination #3 to t = 0.012000
# 16:13:36.652 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #3 over 7 time steps
# 16:13:36.652 - GPLaSDI:_rollout_setup:868 - INFO - We will rollout each frame for parameter combination #3 over 7 time steps
# 16:13:36.656 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #3.
# 16:13:36.656 - GPLaSDI:_rollout_setup:882 - INFO - We will rollout 495 FOM frames for parameter combination #3.
# 16:13:36.757 - GPLaSDI:train:707 - INFO - Iter: 00101/900, Total: 0.0223680902, Recon: 0.0144133084, LD: 0.0000021182, Coef: 8.2002849579, max|c|: 01.1,
# 16:13:36.757 - GPLaSDI:train:707 - INFO - Iter: 00101/900, Total: 0.0223680902, Recon: 0.0144133084, LD: 0.0000021182, Coef: 8.2002849579, max|c|: 01.1,
# 16:13:36.786 - GPLaSDI:train:707 - INFO - Iter: 00102/900, Total: 0.0222040340, Recon: 0.0143108545, LD: 0.0000022155, Coef: 8.0973320007, max|c|: 01.1,
# 16:13:36.786 - GPLaSDI:train:707 - INFO - Iter: 00102/900, Total: 0.0222040340, Recon: 0.0143108545, LD: 0.0000022155, Coef: 8.0973320007, max|c|: 01.1,
# 16:13:36.812 - GPLaSDI:train:707 - INFO - Iter: 00103/900, Total: 0.0220395848, Recon: 0.0142072029, LD: 0.0000022947, Coef: 8.0060882568, max|c|: 01.0,
# 16:13:36.812 - GPLaSDI:train:707 - INFO - Iter: 00103/900, Total: 0.0220395848, Recon: 0.0142072029, LD: 0.0000022947, Coef: 8.0060882568, max|c|: 01.0,
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# torch.Size([501, 1001])
# 501
# 16:13:36.836 - GPLaSDI:train:707 - INFO - Iter: 00104/900, Total: 0.0218755025, Recon: 0.0141043635, LD: 0.0000023171, Coef: 7.9059429169, max|c|: 01.0,
# 16:13:36.836 - GPLaSDI:train:707 - INFO - Iter: 00104/900, Total: 0.0218755025, Recon: 0.0141043635, LD: 0.0000023171, Coef: 7.9059429169, max|c|: 01.0,
# 16:14:22.482 - GPLaSDI:train:707 - INFO - Iter: 00899/900, Total: 0.0038071678, Recon: 0.0021423732, LD: 0.0000043620, Coef: 5.9934978485, max|c|: 00.6,
# 16:14:22.482 - GPLaSDI:train:707 - INFO - Iter: 00899/900, Total: 0.0038071678, Recon: 0.0021423732, LD: 0.0000043620, Coef: 5.9934978485, max|c|: 00.6,
# 16:14:22.521 - GPLaSDI:train:707 - INFO - Iter: 00900/900, Total: 0.0022262768, Recon: 0.0010949875, LD: 0.0000043026, Coef: 5.9842920303, max|c|: 00.6,
# 16:14:22.521 - GPLaSDI:train:707 - INFO - Iter: 00900/900, Total: 0.0022262768, Recon: 0.0010949875, LD: 0.0000043026, Coef: 5.9842920303, max|c|: 00.6,
# /Users/stephany1/Documents/Projects/Second Order LaSDI/src/GPLaSDI.py:745: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict  = torch.load(self.path_checkpoint + '/' + 'checkpoint.pt');
# 16:14:22.525 - Plot:Plot_Reconstruction:111 - INFO - Making a Reconstruction plot with n_t = 501, n_x = 1001, and n_IC = 1
# 16:14:22.525 - Plot:Plot_Reconstruction:111 - INFO - Making a Reconstruction plot with n_t = 501, n_x = 1001, and n_IC = 1
# Function name      	Calls	Total time	Time/call
#
# Rollout Setup      	4511	2.528e+00	5.604e-04
#
# train_step         	900	3.007e+01	3.341e-02
#
# Forward Pass       	4500	3.136e+00	6.968e-04
#
# Reconstruction Loss	4500	9.352e-01	2.078e-04
#
# Calibration        	900	1.104e+00	1.226e-03
#
# Rollout Loss       	900	6.429e+00	7.144e-03
#
# Backwards Pass     	900	1.476e+01	1.640e-02
#
# Report             	900	7.665e-01	8.517e-04
#
# finalize           	3	3.959e-03	1.320e-03
#
# new_sample         	2	1.147e+01	5.733e+00

# %% [markdown]
# # Loading From a Save
#
#
# If you instead want to load a saved model, we can load the restart file for post-training.

# %%
# Add src directory to the search path
import  os;
import  sys;
src_path    : str = os.path.join(os.path.abspath(os.path.pardir), "src");
sys.path.append(src_path);

import  yaml;
import  logging;

import  numpy; 
import  torch;

from    ParameterSpace  import  ParameterSpace;
from    Initialize      import  Initialize_Trainer;



# Specify the restart file you have.
filename    : str   =  'lasdi_02_21_2025_15_57.npy'
cfg_file    : str   = 'burgers.yml'
with open(cfg_file, 'r') as f:
    config = yaml.safe_load(f)

file_path   : str   = os.path.join(os.path.join(os.path.pardir, "results"), filename);
restart_file = numpy.load(file_path, allow_pickle = True).item()

trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config, restart_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 25
#      22     config = yaml.safe_load(f)
#      24 file_path   : str   = os.path.join(os.path.join(os.path.pardir, "results"), filename);
# ---> 25 restart_file = numpy.load(file_path, allow_pickle = True).item()
#      27 trainer, param_space, physics, model, latent_dynamics = Initialize_Trainer(config, restart_file)
#
# File ~/miniconda3/envs/LaSDI/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/lasdi_02_21_2025_15_57.npy'

# %% [markdown]
# # Post-processing

# %% [markdown]
# Setup data for post-processing:

# %%
n_coef          : int                       = latent_dynamics.n_coefs;
n_IC            : int                       = latent_dynamics.n_IC; 
n_p             : int                       = param_space.n_p; 

coefs           : numpy.ndarray             = trainer.best_coefs;           # shape = (n_train, n_coefs).
X_Train         : list[list[torch.Tensor]]  = trainer.X_Train;              # len = n_train. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM train solve
X_Test          : list[list[torch.Tensor]]  = trainer.X_Test;               # len = n_test. i'th element is a list of length n_IC. j'th element has length (n_t(i), n_x); holds j'th derivative of i'th FOM test solve.
t_Train         : list[torch.Tensor]        = trainer.t_Train;              # len = n_train. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM train solve.
t_Test          : list[torch.Tensor]        = trainer.t_Test;               # len = n_test. i'th element is a numpy.ndarray of shape (n_t(i)) whose j'th element holds the j'th time value for the i'th FOM test solve.
n_samples       : int                       = trainer.n_samples;

param_train     : numpy.ndarray             = param_space.train_space;      # shape = (n_train, n_p)
param_test      : numpy.ndarray             = param_space.test_space;       # shape = (n_test, n_p)
param_names     : list[str]                 = param_space.param_names;

test_meshgrid   : tuple[numpy.ndarray]      = param_space.test_meshgrid;    # len = n_p. i'th element is meshgrid for i'th parameter.
test_grid_sizes : list[int]                 = param_space.test_grid_sizes;  # len = n_p. i'th element holds the number of values of the i'th parameter in the test set.
n_init_train    : int                       = param_space.n_init_train;     # The initial number of combinations of parameters in the training set.
n_train         : int                       = param_space.n_train();
n_test          : int                       = param_space.n_test();

X_Positions     : numpy.ndarray             = physics.X_Positions;          # Spatial discretization of FOM problem domain.
assert(X_Positions.ndim == 1);

# %% [markdown]
# ## Gaussian-process uncertainty evaluation
# For each combination of parameters, evaluate the coefficient GPs to generate a set of coefficients for the latent dynamics for that parameter combination. Then solve each latent dynamics forward in time.

# %%
# First, we need to import a few new things.
import os;
import sys;
physics_path    : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Physics");
utils_path      : str   = os.path.join(os.path.join(os.path.pardir, "src"), "Utilities");
sys.path.append(physics_path);

from    sklearn.gaussian_process    import  GaussianProcessRegressor;

import  SolveROMs;
import  GaussianProcess;
from    Physics                     import  Physics;
from    Model                       import  Autoencoder, Autoencoder_Pair;

# Setup
model.cpu();



# Get a GP for each coefficient in the latent dynamics.
gp_list         : list[GaussianProcessRegressor]    = GaussianProcess.fit_gps(param_space.train_space, coefs);

Zis_samples     : list[list[numpy.ndarray]] = SolveROMs.sample_roms(model, physics, latent_dynamics, gp_list, param_test, t_Test, n_samples);    # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_samples, n_z)
Zis_mean        : list[list[numpy.ndarray]] = SolveROMs.average_rom(model, physics, latent_dynamics, gp_list, param_test, t_Test);               # len = n_test. i'th element is an n_IC element list whose j'th element has shape (n_t(i), n_z)
# Out:
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %% [markdown]
# Now, decode the latent trajectories and compare them to the test set. Use these values to compute some errors.

# %%
# Set up arrays to hold the average error between X_pred_mean and X_test, as well as the std of 
# the predictions.
mean_rel_error   : list[numpy.ndarray]   = [];
max_std          : list[numpy.ndarray]   = [];
for d in range(n_IC):
    mean_rel_error.append(  numpy.zeros(n_test, dtype = numpy.float32));
    max_std.append(         numpy.zeros(n_test, dtype = numpy.float32));



# Pass the samples through the decoder. The way this works depends on what kind of model we are using. 
if(isinstance(model, Autoencoder)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        X_pred_mean.append([model.Decode(torch.Tensor(Zis_mean[i][0])).detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_X_Pred   : numpy.ndarray            = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            X_Pred_ij                           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]));
            ith_X_Pred[:, j, :]                 = X_Pred_ij.detach().numpy();

        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_X_Pred.std(axis = 1).max();
    
    

elif(isinstance(model, Autoencoder_Pair)):
    # Decode the mean predictions.
    X_pred_mean     : list[list[numpy.ndarray]]     = [];   # len = n_test. i'th element has len n_IC whose j'th element has shape (n_t_i, n_x).
    for i in range(n_test):
        Disp_Pred_mean_i, Vel_Pred_mean_i   = model.Decode(torch.Tensor(Zis_mean[i][0]), torch.Tensor(Zis_mean[i][1]));
        X_pred_mean.append([Disp_Pred_mean_i.detach().numpy(), Vel_Pred_mean_i.detach().numpy()]);

    # Decode the Zis for each parameter and compute the corresponding STDs. 
    for i in range(n_test):
        # Decode the latent trajectories for each sample of the i'th combination of parameter values.
        n_t_i           : int                   = len(t_Test[i]);
        n_x             : int                   = len(X_Positions);

        ith_Disp_Pred   : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);
        ith_Vel_Pred    : numpy.ndarray         = numpy.empty((n_t_i, n_samples, n_x), dtype = numpy.float32);

        for j in range(n_samples):
            Disp_Pred_ij, Vel_Pred_ij           = model.Decode(torch.Tensor(Zis_samples[i][0][:, j, :]), torch.Tensor(Zis_samples[i][1][:, j, :]));
            ith_Disp_Pred[:, j, :]              = Disp_Pred_ij.detach().numpy();
            ith_Vel_Pred[:, j, :]               = Vel_Pred_ij.detach().numpy();


        # Find the std of the frame of the position and velocity reconstruction with the i'th 
        # combination of parameter values that has the greatest variance.
        max_std[0][i]                           = ith_Disp_Pred.std(axis = 1).max();
        max_std[1][i]                           = ith_Vel_Pred.std(axis = 1).max();



# For each d \in {0, 1, ... , n_{IC} - 1} and k \in {1, 2, ... , n_test - 1}, find the mean 
# error between X_Pred_mean[d][k, ...] and X_test[d][k, ...].
for d in range(n_IC):
    for k in range(n_test):        
        # Extract the prediction, true values for the d'th component of the fom solution when we use 
        # the k'th parameter value. These have shape (n_t, n_x).
        kth_X_Pred_d            : numpy.ndarray = X_pred_mean[k][d];
        kth_X_Test_d            : numpy.ndarray = X_Test[k][d].numpy();
        
        # For each compute the relative error between the predicted and true values of the d'th 
        # derivative of the fom solution at each time step when we use the k'th combination of 
        # parameter values.
        kth_Relative_Errors_d   : numpy.ndarray = numpy.linalg.norm(kth_X_Pred_d - kth_X_Test_d, axis = 1) / numpy.linalg.norm(kth_X_Test_d, axis = 1);
        mean_rel_error[d][k]                    = kth_Relative_Errors_d.max();



# Get the mean and std of each coefficient's distribution when we evaluate the posterior coefficient 
# distributions at each testing parameter value. We then reshape these arrays to have shape 
# (N(1), ... , N(n_p)), where N(k) is the number of distinct values of the k'th parameter in the 
# training set. The i(1), ... , i(n_p), j element of the d'th element of these lists will hold the 
# mean and std of the distribution of the j'th parameter when we use the i(k)'th value of the k'th 
# parameter.
gp_pred_mean, gp_pred_std = GaussianProcess.eval_gp(gp_list, param_test);
gp_pred_mean    = gp_pred_mean.reshape(test_grid_sizes + [-1]);
gp_pred_std     = gp_pred_std.reshape(test_grid_sizes + [-1]);

# Reshape each element of mean_rel_error and max_std has shape (N(1), ... , N(n_p)), where N(k) 
# is the number of distinct values of the k'th parameter in the training set. The i(1), ... , i(n_p) 
# element of the d'th element of these lists will hold the mean error and std of the prediction of 
# the d'th derivative of the fom solution when we use the i(k)'th value of the k'th parameter, 
# respectively.
for d in range(n_IC):
    mean_rel_error[d]   = mean_rel_error[d].reshape(test_grid_sizes);
    max_std[d]          = max_std[d].reshape(test_grid_sizes);

# %% [markdown]
# # Visualization

# %% [markdown]
# Plot mean and standard deviation of coefficient matrix.
# For SINDy of dimension 5, the coefficient matrix has a shape of (6, 5).

# %%
import  Plot;

if(n_p == 2):
    Plot.Plot_GP2d( p1_mesh     = test_meshgrid[0], 
                    p2_mesh     = test_meshgrid[1], 
                    gp_mean     = gp_pred_mean, 
                    gp_std      = gp_pred_std, 
                    param_train = param_train, 
                    param_names = param_names, 
                    n_cols      = 5);
# Out:
# 16:19:46.674 - Plot:Plot_GP2d:498 - INFO - Producing GP plots with 30 coefficients. The parameters are ['a', 'w']
# 16:19:46.674 - Plot:Plot_GP2d:498 - INFO - Producing GP plots with 30 coefficients. The parameters are ['a', 'w']

# %%
for d in range(n_IC):
    if(d == 0):
        title_string : str = r'$max_{t} mean_{i} \|x \to \left(\tilde{u}_{\xi^*}^{i}(t, x) - u(t, x) \right) \|/\| x \to u(t, x)\|$';
    else:
        title_string : str = r'$max_{t} mean_{i} \left\|x \to \left( \frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*}^{i}(t, x) - \frac{d^{%d}}{dt^{%d}}u(t, x) \right) \right\|$' % (d, d, d, d);


    Plot.Plot_Heatmap2d(values          = mean_rel_error[d] * 100, 
                        p1_grid         = test_meshgrid[0][:, 0], 
                        p2_grid         = test_meshgrid[1][0, :], 
                        param_train     = param_train, 
                        n_init_train    = param_space.n_init_train, 
                        param_names     = param_names, 
                        title           = title_string);
# Out:
# 16:19:51.178 - Plot:Plot_Heatmap2d:682 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 6 training points (4 initial) and 25 testing points.
# 16:19:51.178 - Plot:Plot_Heatmap2d:682 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 6 training points (4 initial) and 25 testing points.

# %%
import Plot; 

for d in range(n_IC):
    if(d == 0):
        title : str = r'$max_{(t, x)} \sqrt{ V \left[ \tilde{u}_{\xi^*} \right] }$';
    else:
        title : str = r'$max_{(t, x)} \sqrt{ V \left[\frac{d^{%d}}{dt^{%d}}\tilde{u}_{\xi^*} \right] }$' % (d, d);


    Plot.Plot_Heatmap2d(values          = max_std[d] * 100, 
                        p1_grid         = test_meshgrid[0][:, 0], 
                        p2_grid         = test_meshgrid[1][0, :], 
                        param_train     = param_train, 
                        n_init_train    = param_space.n_init_train, 
                        param_names     = param_names, 
                        title           = title);
# Out:
# 16:19:55.687 - Plot:Plot_Heatmap2d:682 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 6 training points (4 initial) and 25 testing points.
# 16:19:55.687 - Plot:Plot_Heatmap2d:682 - INFO - Making heatmap. Parameters = ['a', 'w']. There are 6 training points (4 initial) and 25 testing points.

# %%
import importlib
importlib.reload(Plot);

# Pick some parameter values.
a           : float                 = 0.9;
w           : float                 = 1.07; 
param_grid  : numpy.ndarray         = numpy.array([[a, w]]);

# Get the predicted solution using this parameter value.
X_True, t_Grid = physics.solve(param_grid[0]);


# Plot the predictions!
Plot.Plot_Prediction(
            model           = model, 
            physics         = physics, 
            latent_dynamics = latent_dynamics, 
            param_grid      = param_grid,
            gp_list         = gp_list, 
            n_samples       = n_samples, 
            X_True          = [X_True], 
            t_Grid          = [t_Grid]);
# Out:
# /Users/stephany1/miniconda3/envs/LaSDI/lib/python3.10/site-packages/scipy/sparse/_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# 16:19:58.948 - Plot:Plot_Prediction:275 - INFO - Solving the latent dynamics using 20 samples of the posterior distributions for 1 combinations of parameter values
# 16:19:58.948 - Plot:Plot_Prediction:275 - INFO - Solving the latent dynamics using 20 samples of the posterior distributions for 1 combinations of parameter values
# 16:19:59.112 - Plot:Plot_Prediction:310 - INFO - Computing mean/std of predictions for combination number 0.
# 16:19:59.112 - Plot:Plot_Prediction:310 - INFO - Computing mean/std of predictions for combination number 0.
# 16:19:59.112 - Plot:Plot_Prediction:311 - INFO - The Latent Trajectories combination number 0 has shape (n_t(0), n_samples, n_z) = (501, 20, 5)
# 16:19:59.112 - Plot:Plot_Prediction:311 - INFO - The Latent Trajectories combination number 0 has shape (n_t(0), n_samples, n_z) = (501, 20, 5)
